# %% [markdown]
# <a href="https://colab.research.google.com/github/seeedata/BADA/blob/main/BADATON/%EC%A7%80%ED%95%98%EC%B2%A0%20%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EC%A0%84%EC%B2%98%EB%A6%AC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # Import

# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# #2022년 12월

# %%
sub2212 = pd.read_csv('/content/drive/MyDrive/BADA/바다톤/data/CARD_SUBWAY_MONTH_2022 (1).csv', index_col=False, encoding='cp949')
sub2212
# Out:
#             사용일자  노선명       역명  승차총승객수  하차총승객수      등록일자
# 0       20220101  3호선       수서    7370    7076  20220104
# 1       20220101  3호선      학여울     461     473  20220104
# 2       20220101  3호선       대청    3224    2903  20220104
# 3       20220101  3호선       일원    3321    2803  20220104
# 4       20220101  경원선       창동       1       0  20220104
# ...          ...  ...      ...     ...     ...       ...
# 219740  20221231  4호선      신용산   11025   12099  20230103
# 219741  20221231  경부선       석수    5643    5147  20230103
# 219742  20221231  경부선     금천구청    7519    7426  20230103
# 219743  20221231  경부선  가산디지털단지    5579    7299  20230103
# 219744  20221231  경부선       구로   11318   12080  20230103
#
# [219745 rows x 6 columns]

# %%
sub2212.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 219745 entries, 0 to 219744
# Data columns (total 6 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   사용일자    219745 non-null  int64
#  1   노선명     219745 non-null  object
#  2   역명      219745 non-null  object
#  3   승차총승객수  219745 non-null  int64
#  4   하차총승객수  219745 non-null  int64
#  5   등록일자    219745 non-null  int64
# dtypes: int64(4), object(2)
# memory usage: 10.1+ MB

# %%
#12.01 ~ 12.31 추출
sub2212 = sub2212[sub2212['사용일자']>=20221201]
sub2212
# Out:
#             사용일자  노선명       역명  승차총승객수  하차총승객수      등록일자
# 200943  20221201  수인선       연수    4695    4594  20221204
# 200944  20221201  수인선       송도    2482    2346  20221204
# 200945  20221201  수인선      인하대    7437    7016  20221204
# 200946  20221201  수인선       숭의    3987    3802  20221204
# 200947  20221201  수인선       신포    1771    1833  20221204
# ...          ...  ...      ...     ...     ...       ...
# 219740  20221231  4호선      신용산   11025   12099  20230103
# 219741  20221231  경부선       석수    5643    5147  20230103
# 219742  20221231  경부선     금천구청    7519    7426  20230103
# 219743  20221231  경부선  가산디지털단지    5579    7299  20230103
# 219744  20221231  경부선       구로   11318   12080  20230103
#
# [18802 rows x 6 columns]

# %%
#승차총승객수, 등록일자 열 제거
sub2212 = sub2212.drop(['승차총승객수', '등록일자'], axis=1); sub2212
# Out:
#             사용일자  노선명       역명  하차총승객수
# 200943  20221201  수인선       연수    4594
# 200944  20221201  수인선       송도    2346
# 200945  20221201  수인선      인하대    7016
# 200946  20221201  수인선       숭의    3802
# 200947  20221201  수인선       신포    1833
# ...          ...  ...      ...     ...
# 219740  20221231  4호선      신용산   12099
# 219741  20221231  경부선       석수    5147
# 219742  20221231  경부선     금천구청    7426
# 219743  20221231  경부선  가산디지털단지    7299
# 219744  20221231  경부선       구로   12080
#
# [18802 rows x 4 columns]

# %%
sub2212['역명'].unique()
# Out:
# array(['연수', '송도', '인하대', '숭의', '신포', '인천', '샛강', '대방', '서울지방병무청', '보라매',
#        '보라매공원', '보라매병원', '당곡', '신림', '서원', '서울대벤처타운', '관악산(서울대)', '산본',
#        '대야미', '반월', '상록수', '한대앞', '중앙', '고잔', '초지', '안산', '신길온천', '정왕',
#        '오이도', '수리산', '원당', '화정', '대곡', '백석', '마두', '정발산', '주엽', '대화',
#        '봉명', '쌍용(나사렛대)', '아산', '탕정', '배방', '온양온천', '신창(순천향대)', '회기', '중랑',
#        '상봉(시외버스터미널)', '망우', '양원', '구리', '도농', '양정', '덕소', '도심', '팔당',
#        '운길산', '양수', '신원', '국수', '아신', '오빈', '양평', '원덕', '용문', '지평', '수색',
#        '가좌', '홍대입구', '화전', '서강대', '공덕', '효창공원앞', '신촌', '서울역', '소요산',
#        '디지털미디어시티', '동두천', '보산', '동두천중앙', '지행', '덕정', '덕계', '양주', '녹양',
#        '가능', '의정부', '회룡', '망월사', '도봉산', '도봉', '방학', '녹천', '월계', '광운대',
#        '석계', '신이문', '외대앞', '청량리(서울시립대입구)', '왕십리(성동구청)', '응봉', '옥수', '한남',
#        '서빙고', '이촌(국립중앙박물관)', '광명', '서동탄', '당정', '천안', '두정', '직산', '성환',
#        '평택', '평택지제', '서정리', '송탄', '진위', '오산', '오산대', '세마', '병점', '세류',
# ...

# %%
#역명
stations = [
            '잠실나루', '잠실(송파구청)', '잠실새내', '종합운동장', '가락시장', '경찰병원', '오금', '올림픽공원(한국체대)', '방이', '개롱', '거여', '마천', '몽촌토성(평화의문)', '석촌', '송파', '문정', '장지', '복정', '삼전', '석촌고분', '송파나루', '한성백제',
            '방화', '개화산', '김포공항', '송정', '마곡', '발산', '우장산', '화곡', '까치산', '개화', '공항시장', '신방화', '마곡나루(서울식물원)', '양천향교', '가양', '증미', '등촌',
            '삼성(무역센터)', '선릉', '역삼', '강남', '압구정', '신사', '매봉', '도곡', '대치', '학여울', '대청', '일원', '수서', '청담', '강남구청', '학동', '논현', '언주', '선정릉', '삼성중앙', '봉은사', '신논현', '압구정로데오', '한티', '구룡', '개포동', '대모산입구',
            '당고개', '상계', '노원', '석계', '태릉입구', '화랑대(서울여대입구)', '수락산', '마들', '중계', '하계', '공릉(서울과학기술대)', '월계', '광운대',
            '낙성대(강감찬)', '서울대입구(관악구청)', '봉천', '신림', '당곡', '서원', '서울대벤처타운', '관악산(서울대)'
            ]

# %%
sub2212 = sub2212.loc[sub2212['역명'].isin(stations)] ; sub2212
# Out:
#             사용일자  노선명        역명  하차총승객수
# 200955  20221201  신림선        당곡    4143
# 200956  20221201  신림선        신림    2338
# 200957  20221201  신림선        서원    2846
# 200958  20221201  신림선   서울대벤처타운    7628
# 200959  20221201  신림선  관악산(서울대)    2234
# ...          ...  ...       ...     ...
# 219634  20221231  3호선        도곡    2468
# 219675  20221231  5호선        마천    4426
# 219676  20221231  5호선        거여    5411
# 219678  20221231  경의선      김포공항       0
# 219681  20221231  분당선        복정       0
#
# [3275 rows x 4 columns]

# %%
sub2212.isnull().sum()
# Out:
# 사용일자      0
# 노선명       0
# 역명        0
# 하차총승객수    0
# dtype: int64

# %%
stations_송파 = ['잠실나루', '잠실(송파구청)', '잠실새내', '종합운동장', '가락시장', '경찰병원', '오금', '올림픽공원(한국체대)', '방이', '개롱', '거여', '마천', '몽촌토성(평화의문)', '석촌', '송파', '문정', '장지', '복정', '삼전', '석촌고분', '송파나루', '한성백제']
stations_강서 = ['방화', '개화산', '김포공항', '송정', '마곡', '발산', '우장산', '화곡', '까치산', '개화', '공항시장', '신방화', '마곡나루(서울식물원)', '양천향교', '가양', '증미', '등촌']
stations_강남 = ['삼성(무역센터)', '선릉', '역삼', '강남', '압구정', '신사', '매봉', '도곡', '대치', '학여울', '대청', '일원', '수서', '청담', '강남구청', '학동', '논현', '언주', '선정릉', '삼성중앙', '봉은사', '신논현', '압구정로데오', '한티', '구룡', '개포동', '대모산입구']
stations_노원 = ['당고개', '상계', '노원', '석계', '태릉입구', '화랑대(서울여대입구)', '수락산', '마들', '중계', '하계', '공릉(서울과학기술대)', '월계', '광운대']
stations_관악 = ['낙성대(강감찬)', '서울대입구(관악구청)', '봉천', '신림', '당곡', '서원', '서울대벤처타운', '관악산(서울대)']

# %%
sub2212.loc[sub2212['역명'].isin(stations_송파), 'area'] = '송파구'
sub2212.loc[sub2212['역명'].isin(stations_강서), 'area'] = '강서구'
sub2212.loc[sub2212['역명'].isin(stations_강남), 'area'] = '강남구'
sub2212.loc[sub2212['역명'].isin(stations_노원), 'area'] = '노원구'
sub2212.loc[sub2212['역명'].isin(stations_관악), 'area'] = '관악구'
sub2212
# Out:
#             사용일자  노선명        역명  하차총승객수 area
# 200955  20221201  신림선        당곡    4143  관악구
# 200956  20221201  신림선        신림    2338  관악구
# 200957  20221201  신림선        서원    2846  관악구
# 200958  20221201  신림선   서울대벤처타운    7628  관악구
# 200959  20221201  신림선  관악산(서울대)    2234  관악구
# ...          ...  ...       ...     ...  ...
# 219634  20221231  3호선        도곡    2468  강남구
# 219675  20221231  5호선        마천    4426  송파구
# 219676  20221231  5호선        거여    5411  송파구
# 219678  20221231  경의선      김포공항       0  강서구
# 219681  20221231  분당선        복정       0  송파구
#
# [3275 rows x 5 columns]

# %%
sub2212.isnull().sum()
# Out:
# 사용일자      0
# 노선명       0
# 역명        0
# 하차총승객수    0
# area      0
# dtype: int64

# %%
sub2212_group = sub2212.groupby(['사용일자', 'area']).sum(); sub2212_group
# Out:
#                하차총승객수
# 사용일자     area
# 20221201 강남구   690730
#          강서구   235186
#          관악구   173855
#          노원구   205567
#          송파구   329212
# ...               ...
# 20221231 강남구   340027
#          강서구   140370
#          관악구   116160
#          노원구   131549
#          송파구   236602
#
# [155 rows x 1 columns]

# %%
sub2212_group.to_csv('/content/drive/MyDrive/BADA/바다톤/data/22년12월_지하철_일별_지역구별_하차승객수.csv')

# %% [markdown]
# #2023년 1월

# %%
sub2301 = pd.read_csv('/content/drive/MyDrive/BADA/바다톤/data/CARD_SUBWAY_MONTH_202301.csv', index_col=False)
sub2301
# Out:
#            사용일자  노선명     역명  승차총승객수  하차총승객수      등록일자
# 0      20230101  경강선    곤지암    1450    1539  20230104
# 1      20230101  2호선    신도림   20210   21037  20230104
# 2      20230101  2호선     문래    5995    6567  20230104
# 3      20230101  2호선  영등포구청    5629    6117  20230104
# 4      20230101  2호선     당산    6821    7594  20230104
# ...         ...  ...    ...     ...     ...       ...
# 18792  20230131  경원선    소요산    2244    1929  20230203
# 18793  20230131  경원선    동두천    1988    2188  20230203
# 18794  20230131  경원선     보산    1391    1299  20230203
# 18795  20230131  경원선  동두천중앙    3046    2954  20230203
# 18796  20230131  경원선     지행    6220    6187  20230203
#
# [18797 rows x 6 columns]

# %%
sub2301.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18797 entries, 0 to 18796
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   사용일자    18797 non-null  int64
#  1   노선명     18797 non-null  object
#  2   역명      18797 non-null  object
#  3   승차총승객수  18797 non-null  int64
#  4   하차총승객수  18797 non-null  int64
#  5   등록일자    18797 non-null  int64
# dtypes: int64(4), object(2)
# memory usage: 881.2+ KB

# %%
sub2301 = sub2301.drop(['승차총승객수', '등록일자'], axis=1)
sub2301 = sub2301.loc[sub2301['역명'].isin(stations)]
sub2301.loc[sub2301['역명'].isin(stations_송파), 'area'] = '송파구'
sub2301.loc[sub2301['역명'].isin(stations_강서), 'area'] = '강서구'
sub2301.loc[sub2301['역명'].isin(stations_강남), 'area'] = '강남구'
sub2301.loc[sub2301['역명'].isin(stations_노원), 'area'] = '노원구'
sub2301.loc[sub2301['역명'].isin(stations_관악), 'area'] = '관악구'
sub2301
# Out:
#            사용일자  노선명           역명  하차총승객수 area
# 14     20230101  7호선           노원    8520  노원구
# 15     20230101  7호선           마들    4825  노원구
# 16     20230101  7호선          수락산    6076  노원구
# 20     20230101  6호선  화랑대(서울여대입구)    3759  노원구
# 21     20230101  6호선         태릉입구    2735  노원구
# ...         ...  ...          ...     ...  ...
# 18734  20230131  2호선           강남   87738  강남구
# 18739  20230131  2호선     낙성대(강감찬)   28040  관악구
# 18740  20230131  2호선  서울대입구(관악구청)   48499  관악구
# 18741  20230131  2호선           봉천   24222  관악구
# 18742  20230131  2호선           신림   57368  관악구
#
# [3269 rows x 5 columns]

# %%
sub2301_group = sub2301.groupby(['사용일자', 'area']).sum(); sub2301_group
# Out:
#                하차총승객수
# 사용일자     area
# 20230101 강남구   183548
#          강서구   102607
#          관악구    90979
#          노원구    88050
#          송파구   155279
# ...               ...
# 20230131 강남구   723246
#          강서구   243450
#          관악구   178652
#          노원구   199850
#          송파구   337761
#
# [155 rows x 1 columns]

# %%
sub2301_group.to_csv('/content/drive/MyDrive/BADA/바다톤/data/23년01월_지하철_일별_지역구별_하차승객수.csv')

# %% [markdown]
# #2023년 2월

# %%
sub2302 = pd.read_csv('/content/drive/MyDrive/BADA/바다톤/data/CARD_SUBWAY_MONTH_202302.csv', index_col=False); sub2302
# Out:
#            사용일자  노선명           역명  승차총승객수  하차총승객수      등록일자
# 0      20230201  2호선     낙성대(강감찬)   29187   28243  20230204
# 1      20230201  2호선  서울대입구(관악구청)   49007   48259  20230204
# 2      20230201  2호선           봉천   26118   24509  20230204
# 3      20230201  2호선           신림   59650   57704  20230204
# 4      20230201  2호선          신대방   26647   26197  20230204
# ...         ...  ...          ...     ...     ...       ...
# 16989  20230228  중앙선           팔당     887    1061  20230303
# 16990  20230228  중앙선          운길산     774     654  20230303
# 16991  20230228  중앙선           양수    1933    1983  20230303
# 16992  20230228  중앙선           신원     200     182  20230303
# 16993  20230228  중앙선           국수     795     755  20230303
#
# [16994 rows x 6 columns]

# %%
sub2302.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16994 entries, 0 to 16993
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   사용일자    16994 non-null  int64
#  1   노선명     16994 non-null  object
#  2   역명      16994 non-null  object
#  3   승차총승객수  16994 non-null  int64
#  4   하차총승객수  16994 non-null  int64
#  5   등록일자    16994 non-null  int64
# dtypes: int64(4), object(2)
# memory usage: 796.7+ KB

# %%
sub2302 = sub2302.drop(['승차총승객수', '등록일자'], axis=1)
sub2302 = sub2302.loc[sub2302['역명'].isin(stations)]
sub2302.loc[sub2302['역명'].isin(stations_송파), 'area'] = '송파구'
sub2302.loc[sub2302['역명'].isin(stations_강서), 'area'] = '강서구'
sub2302.loc[sub2302['역명'].isin(stations_강남), 'area'] = '강남구'
sub2302.loc[sub2302['역명'].isin(stations_노원), 'area'] = '노원구'
sub2302.loc[sub2302['역명'].isin(stations_관악), 'area'] = '관악구'
sub2302
# Out:
#            사용일자  노선명           역명  하차총승객수 area
# 0      20230201  2호선     낙성대(강감찬)   28243  관악구
# 1      20230201  2호선  서울대입구(관악구청)   48259  관악구
# 2      20230201  2호선           봉천   24509  관악구
# 3      20230201  2호선           신림   57704  관악구
# 27     20230201  신림선           당곡    4667  관악구
# ...         ...  ...          ...     ...  ...
# 16931  20230228  신림선           당곡    4690  관악구
# 16932  20230228  신림선           신림    2601  관악구
# 16933  20230228  신림선           서원    2893  관악구
# 16934  20230228  신림선      서울대벤처타운    8755  관악구
# 16935  20230228  신림선     관악산(서울대)    2586  관악구
#
# [2956 rows x 5 columns]

# %%
sub2302_group = sub2302.groupby(['사용일자', 'area']).sum(); sub2302_group
# Out:
#                하차총승객수
# 사용일자     area
# 20230201 강남구   731366
#          강서구   246590
#          관악구   179693
#          노원구   202812
#          송파구   343883
# ...               ...
# 20230228 강남구   746825
#          강서구   250891
#          관악구   187058
#          노원구   211008
#          송파구   360984
#
# [140 rows x 1 columns]

# %%
sub2302_group.to_csv('/content/drive/MyDrive/BADA/바다톤/data/23년02월_지하철_일별_지역구별_하차승객수.csv')

# %% [markdown]
# #2023년 3월

# %%
sub2303 = pd.read_csv('/content/drive/MyDrive/BADA/바다톤/data/CARD_SUBWAY_MONTH_202303.csv', index_col=False); sub2303
# Out:
#            사용일자  노선명   역명  승차총승객수  하차총승객수      등록일자
# 0      20230301  수인선   달월      62      61  20230304
# 1      20230301  수인선   사리    3237    2748  20230304
# 2      20230301  수인선   야목     230     196  20230304
# 3      20230301  수인선   어천     751     746  20230304
# 4      20230301  수인선  오목천    2169    1967  20230304
# ...         ...  ...  ...     ...     ...       ...
# 18810  20230331  중앙선   오빈     338     387  20230403
# 18811  20230331  중앙선   양평    3374    3662  20230403
# 18812  20230331  중앙선   원덕     467     484  20230403
# 18813  20230331  중앙선   용문    2032    2215  20230403
# 18814  20230331  중앙선   지평      73      86  20230403
#
# [18815 rows x 6 columns]

# %%
sub2303.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18815 entries, 0 to 18814
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   사용일자    18815 non-null  int64
#  1   노선명     18815 non-null  object
#  2   역명      18815 non-null  object
#  3   승차총승객수  18815 non-null  int64
#  4   하차총승객수  18815 non-null  int64
#  5   등록일자    18815 non-null  int64
# dtypes: int64(4), object(2)
# memory usage: 882.1+ KB

# %%
sub2303 = sub2303.drop(['승차총승객수', '등록일자'], axis=1)
sub2303 = sub2303.loc[sub2303['역명'].isin(stations)]
sub2303.loc[sub2303['역명'].isin(stations_송파), 'area'] = '송파구'
sub2303.loc[sub2303['역명'].isin(stations_강서), 'area'] = '강서구'
sub2303.loc[sub2303['역명'].isin(stations_강남), 'area'] = '강남구'
sub2303.loc[sub2303['역명'].isin(stations_노원), 'area'] = '노원구'
sub2303.loc[sub2303['역명'].isin(stations_관악), 'area'] = '관악구'
sub2303
# Out:
#            사용일자  노선명        역명  하차총승객수 area
# 22     20230301  분당선        수서    8683  강남구
# 23     20230301  분당선     대모산입구    2495  강남구
# 24     20230301  분당선       개포동    2684  강남구
# 25     20230301  분당선        구룡    1419  강남구
# 26     20230301  분당선        도곡    3438  강남구
# ...         ...  ...       ...     ...  ...
# 18770  20230331  신림선        당곡    4819  관악구
# 18771  20230331  신림선        신림    2589  관악구
# 18772  20230331  신림선        서원    3007  관악구
# 18773  20230331  신림선   서울대벤처타운    9265  관악구
# 18774  20230331  신림선  관악산(서울대)    3301  관악구
#
# [3269 rows x 5 columns]

# %%
sub2303_group = sub2303.groupby(['사용일자', 'area']).sum(); sub2303_group
# Out:
#                하차총승객수
# 사용일자     area
# 20230301 강남구   283154
#          강서구   137036
#          관악구   118749
#          노원구   127900
#          송파구   196358
# ...               ...
# 20230331 강남구   757252
#          강서구   258319
#          관악구   192214
#          노원구   226710
#          송파구   405597
#
# [155 rows x 1 columns]

# %%
sub2303_group.to_csv('/content/drive/MyDrive/BADA/바다톤/data/23년03월_지하철_일별_지역구별_하차승객수.csv')

# %% [markdown]
# #데이터 통합

# %%
sub = pd.concat([sub2212_group, sub2301_group, sub2302_group, sub2303_group], axis=0)
sub
# Out:
#                하차총승객수
# 사용일자     area
# 20221201 강남구   690730
#          강서구   235186
#          관악구   173855
#          노원구   205567
#          송파구   329212
# ...               ...
# 20230331 강남구   757252
#          강서구   258319
#          관악구   192214
#          노원구   226710
#          송파구   405597
#
# [605 rows x 1 columns]

# %%
sub.to_csv('/content/drive/MyDrive/BADA/바다톤/data/바다톤_지하철_일별_지역구별_하차승객수.csv')
