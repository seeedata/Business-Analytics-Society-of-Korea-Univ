# %% [markdown]
# <a href="https://colab.research.google.com/github/seeedata/BADA/blob/main/BADATON/%EC%A7%80%ED%95%98%EC%B2%A0%20%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EC%A0%84%EC%B2%98%EB%A6%AC%20%EA%B7%80%EA%B0%80%EC%8B%9C%EA%B0%84.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Import

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# #데이터 불러오기

# %%
subway = pd.read_csv('/content/drive/MyDrive/BADA/바다톤/data/서울시 지하철 호선별 역별 시간대별 승하차 인원 정보_바다톤.csv', index_col=False, encoding='cp949')
subway
# Out:
#           사용월  호선명 지하철역  04시-05시 승차인원  04시-05시 하차인원  05시-06시 승차인원  \
# 0      202306  1호선  동대문           854            33         11997
# 1      202306  1호선  동묘앞           228             2          3088
# 2      202306  1호선  서울역           677            33          8470
# 3      202306  1호선   시청            61             1          2351
# 4      202306  1호선  신설동           494            24          9258
# ...       ...  ...  ...           ...           ...           ...
# 60017  201501  중앙선  운길산             0             0           177
# 60018  201501  중앙선   원덕             1             0           292
# 60019  201501  중앙선   중랑            14             1          4929
# 60020  201501  중앙선   팔당             0             0           161
# 60021  201501  중앙선   회기           436             3         10929
#
#        05시-06시 하차인원  06시-07시 승차인원  06시-07시 하차인원  07시-08시 승차인원  ...  \
# 0              2157          9533          7157         14547  ...
# ...

# %%
subway.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60022 entries, 0 to 60021
# Data columns (total 52 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   사용월           60022 non-null  int64
#  1   호선명           60022 non-null  object
#  2   지하철역          60022 non-null  object
#  3   04시-05시 승차인원  60022 non-null  int64
#  4   04시-05시 하차인원  60022 non-null  int64
#  5   05시-06시 승차인원  60022 non-null  int64
#  6   05시-06시 하차인원  60022 non-null  int64
#  7   06시-07시 승차인원  60022 non-null  int64
#  8   06시-07시 하차인원  60022 non-null  int64
#  9   07시-08시 승차인원  60022 non-null  int64
#  10  07시-08시 하차인원  60022 non-null  int64
#  11  08시-09시 승차인원  60022 non-null  int64
#  12  08시-09시 하차인원  60022 non-null  int64
#  13  09시-10시 승차인원  60022 non-null  int64
#  14  09시-10시 하차인원  60022 non-null  int64
#  15  10시-11시 승차인원  60022 non-null  int64
#  16  10시-11시 하차인원  60022 non-null  int64
#  17  11시-12시 승차인원  60022 non-null  int64
# ...

# %%
subway.columns
# Out:
# Index(['사용월', '호선명', '지하철역', '04시-05시 승차인원', '04시-05시 하차인원', '05시-06시 승차인원',
#        '05시-06시 하차인원', '06시-07시 승차인원', '06시-07시 하차인원', '07시-08시 승차인원',
#        '07시-08시 하차인원', '08시-09시 승차인원', '08시-09시 하차인원', '09시-10시 승차인원',
#        '09시-10시 하차인원', '10시-11시 승차인원', '10시-11시 하차인원', '11시-12시 승차인원',
#        '11시-12시 하차인원', '12시-13시 승차인원', '12시-13시 하차인원', '13시-14시 승차인원',
#        '13시-14시 하차인원', '14시-15시 승차인원', '14시-15시 하차인원', '15시-16시 승차인원',
#        '15시-16시 하차인원', '16시-17시 승차인원', '16시-17시 하차인원', '17시-18시 승차인원',
#        '17시-18시 하차인원', '18시-19시 승차인원', '18시-19시 하차인원', '19시-20시 승차인원',
#        '19시-20시 하차인원', '20시-21시 승차인원', '20시-21시 하차인원', '21시-22시 승차인원',
#        '21시-22시 하차인원', '22시-23시 승차인원', '22시-23시 하차인원', '23시-24시 승차인원',
#        '23시-24시 하차인원', '00시-01시 승차인원', '00시-01시 하차인원', '01시-02시 승차인원',
#        '01시-02시 하차인원', '02시-03시 승차인원', '02시-03시 하차인원', '03시-04시 승차인원',
#        '03시-04시 하차인원', '작업일자'],
#       dtype='object')

# %%
#날짜 추출
subway = subway[(subway['사용월']>=202212) & (subway['사용월']<=202303)]
#열 제거
subway = subway[['사용월', '호선명', '지하철역', '04시-05시 하차인원', '18시-19시 하차인원', '19시-20시 하차인원', '20시-21시 하차인원',
       '21시-22시 하차인원', '22시-23시 하차인원', '23시-24시 하차인원', '00시-01시 하차인원',  '01시-02시 하차인원',  '02시-03시 하차인원',
       '03시-04시 하차인원']]
subway
# Out:
#          사용월  호선명 지하철역  04시-05시 하차인원  18시-19시 하차인원  19시-20시 하차인원  \
# 1841  202303  1호선  동대문             8         22150         21176
# 1842  202303  1호선  동묘앞             2         12211          8498
# 1843  202303  1호선  서울역            35         99606         68805
# 1844  202303  1호선   시청             0         27244         14072
# 1845  202303  1호선  신설동            11         32909         23490
# ...      ...  ...  ...           ...           ...           ...
# 4291  202212  중앙선   원덕             0           819           688
# 4292  202212  중앙선   중랑             2         21037         16622
# 4293  202212  중앙선   지평             0           151           233
# 4294  202212  중앙선   팔당             0          1650           965
# 4295  202212  중앙선   회기             8         78819         60601
#
#       20시-21시 하차인원  21시-22시 하차인원  22시-23시 하차인원  23시-24시 하차인원  00시-01시 하차인원  \
# 1841         14561         12652         11596          8898          2612
# ...

# %%
#역명
stations = [
            '잠실나루', '잠실(송파구청)', '잠실새내', '종합운동장', '가락시장', '경찰병원', '오금', '올림픽공원(한국체대)', '방이', '개롱', '거여', '마천', '몽촌토성(평화의문)', '석촌', '송파', '문정', '장지', '복정', '삼전', '석촌고분', '송파나루', '한성백제',
            '방화', '개화산', '김포공항', '송정', '마곡', '발산', '우장산', '화곡', '까치산', '개화', '공항시장', '신방화', '마곡나루(서울식물원)', '양천향교', '가양', '증미', '등촌',
            '삼성(무역센터)', '선릉', '역삼', '강남', '압구정', '신사', '매봉', '도곡', '대치', '학여울', '대청', '일원', '수서', '청담', '강남구청', '학동', '논현', '언주', '선정릉', '삼성중앙', '봉은사', '신논현', '압구정로데오', '한티', '구룡', '개포동', '대모산입구',
            '당고개', '상계', '노원', '석계', '태릉입구', '화랑대(서울여대입구)', '수락산', '마들', '중계', '하계', '공릉(서울과학기술대)', '월계', '광운대',
            '낙성대(강감찬)', '서울대입구(관악구청)', '봉천', '신림', '당곡', '서원', '서울대벤처타운', '관악산(서울대)'
            ]

# %%
subway = subway.loc[subway['지하철역'].isin(stations)] ; subway
# Out:
#          사용월  호선명         지하철역  04시-05시 하차인원  18시-19시 하차인원  19시-20시 하차인원  \
# 1851  202303  2호선           강남             4        192553        117295
# 1857  202303  2호선     낙성대(강감찬)             0        106169         94866
# 1865  202303  2호선           봉천             5         91477         80321
# 1867  202303  2호선     삼성(무역센터)             1         64759         37607
# 1869  202303  2호선  서울대입구(관악구청)            36        184437        156541
# ...      ...  ...          ...           ...           ...           ...
# 4220  202212  신림선     관악산(서울대)             1          3943          3190
# 4221  202212  신림선           당곡             0         16140         12007
# 4227  202212  신림선      서울대벤처타운             0         29370         23873
# 4229  202212  신림선           서원             0         11009         10406
# 4230  202212  신림선           신림             0         10378          6837
#
#       20시-21시 하차인원  21시-22시 하차인원  22시-23시 하차인원  23시-24시 하차인원  00시-01시 하차인원  \
# ...

# %%
subway.isnull().sum()
# Out:
# 사용월             0
# 호선명             0
# 지하철역            0
# 04시-05시 하차인원    0
# 18시-19시 하차인원    0
# 19시-20시 하차인원    0
# 20시-21시 하차인원    0
# 21시-22시 하차인원    0
# 22시-23시 하차인원    0
# 23시-24시 하차인원    0
# 00시-01시 하차인원    0
# 01시-02시 하차인원    0
# 02시-03시 하차인원    0
# 03시-04시 하차인원    0
# dtype: int64

# %%
stations_송파 = ['잠실나루', '잠실(송파구청)', '잠실새내', '종합운동장', '가락시장', '경찰병원', '오금', '올림픽공원(한국체대)', '방이', '개롱', '거여', '마천', '몽촌토성(평화의문)', '석촌', '송파', '문정', '장지', '복정', '삼전', '석촌고분', '송파나루', '한성백제']
stations_강서 = ['방화', '개화산', '김포공항', '송정', '마곡', '발산', '우장산', '화곡', '까치산', '개화', '공항시장', '신방화', '마곡나루(서울식물원)', '양천향교', '가양', '증미', '등촌']
stations_강남 = ['삼성(무역센터)', '선릉', '역삼', '강남', '압구정', '신사', '매봉', '도곡', '대치', '학여울', '대청', '일원', '수서', '청담', '강남구청', '학동', '논현', '언주', '선정릉', '삼성중앙', '봉은사', '신논현', '압구정로데오', '한티', '구룡', '개포동', '대모산입구']
stations_노원 = ['당고개', '상계', '노원', '석계', '태릉입구', '화랑대(서울여대입구)', '수락산', '마들', '중계', '하계', '공릉(서울과학기술대)', '월계', '광운대']
stations_관악 = ['낙성대(강감찬)', '서울대입구(관악구청)', '봉천', '신림', '당곡', '서원', '서울대벤처타운', '관악산(서울대)']

# %%
subway.loc[subway['지하철역'].isin(stations_송파), 'area'] = '송파구'
subway.loc[subway['지하철역'].isin(stations_강서), 'area'] = '강서구'
subway.loc[subway['지하철역'].isin(stations_강남), 'area'] = '강남구'
subway.loc[subway['지하철역'].isin(stations_노원), 'area'] = '노원구'
subway.loc[subway['지하철역'].isin(stations_관악), 'area'] = '관악구'
subway
# Out:
# <ipython-input-11-2837bc6cba12>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   subway.loc[subway['지하철역'].isin(stations_송파), 'area'] = '송파구'
#          사용월  호선명         지하철역  04시-05시 하차인원  18시-19시 하차인원  19시-20시 하차인원  \
# 1851  202303  2호선           강남             4        192553        117295
# 1857  202303  2호선     낙성대(강감찬)             0        106169         94866
# 1865  202303  2호선           봉천             5         91477         80321
# 1867  202303  2호선     삼성(무역센터)             1         64759         37607
# 1869  202303  2호선  서울대입구(관악구청)            36        184437        156541
# ...      ...  ...          ...           ...           ...           ...
# 4220  202212  신림선     관악산(서울대)             1          3943          3190
# ...

# %%
subway.isnull().sum()
# Out:
# 사용월             0
# 호선명             0
# 지하철역            0
# 04시-05시 하차인원    0
# 18시-19시 하차인원    0
# 19시-20시 하차인원    0
# 20시-21시 하차인원    0
# 21시-22시 하차인원    0
# 22시-23시 하차인원    0
# 23시-24시 하차인원    0
# 00시-01시 하차인원    0
# 01시-02시 하차인원    0
# 02시-03시 하차인원    0
# 03시-04시 하차인원    0
# area            0
# dtype: int64

# %%
subway.columns = ['month', 'station_num', 'station_name', '04-05', '18-19', '19-20', '20-21', '21-22', '22-23', '23-24', '00-01', '01-02', '02-03', '03-04', 'area']
subway
# Out:
#        month station_num station_name  04-05   18-19   19-20  20-21  21-22  \
# 1851  202303         2호선           강남      4  192553  117295  60236  47709
# 1857  202303         2호선     낙성대(강감찬)      0  106169   94866  59829  56458
# 1865  202303         2호선           봉천      5   91477   80321  48869  45952
# 1867  202303         2호선     삼성(무역센터)      1   64759   37607  19084  15492
# 1869  202303         2호선  서울대입구(관악구청)     36  184437  156541  94060  87179
# ...      ...         ...          ...    ...     ...     ...    ...    ...
# 4220  202212         신림선     관악산(서울대)      1    3943    3190   2206   1810
# 4221  202212         신림선           당곡      0   16140   12007   7024   6321
# 4227  202212         신림선      서울대벤처타운      0   29370   23873  14981  14057
# 4229  202212         신림선           서원      0   11009   10406   6573   6144
# 4230  202212         신림선           신림      0   10378    6837   3779   3563
#
#       22-23  23-24  00-01  01-02  02-03  03-04 area
# ...

# %%
subway = subway.reset_index(drop=True); subway
# Out:
#       month station_num station_name  04-05   18-19   19-20  20-21  21-22  \
# 0    202303         2호선           강남      4  192553  117295  60236  47709
# 1    202303         2호선     낙성대(강감찬)      0  106169   94866  59829  56458
# 2    202303         2호선           봉천      5   91477   80321  48869  45952
# 3    202303         2호선     삼성(무역센터)      1   64759   37607  19084  15492
# 4    202303         2호선  서울대입구(관악구청)     36  184437  156541  94060  87179
# ..      ...         ...          ...    ...     ...     ...    ...    ...
# 422  202212         신림선     관악산(서울대)      1    3943    3190   2206   1810
# 423  202212         신림선           당곡      0   16140   12007   7024   6321
# 424  202212         신림선      서울대벤처타운      0   29370   23873  14981  14057
# 425  202212         신림선           서원      0   11009   10406   6573   6144
# 426  202212         신림선           신림      0   10378    6837   3779   3563
#
#      22-23  23-24  00-01  01-02  02-03  03-04 area
# ...

# %%
subway = subway[['month', 'area', 'station_num', 'station_name', '18-19', '19-20', '20-21', '21-22', '22-23', '23-24', '00-01', '01-02', '02-03', '03-04', '04-05']]
subway
# Out:
#       month area station_num station_name   18-19   19-20  20-21  21-22  \
# 0    202303  강남구         2호선           강남  192553  117295  60236  47709
# 1    202303  관악구         2호선     낙성대(강감찬)  106169   94866  59829  56458
# 2    202303  관악구         2호선           봉천   91477   80321  48869  45952
# 3    202303  강남구         2호선     삼성(무역센터)   64759   37607  19084  15492
# 4    202303  관악구         2호선  서울대입구(관악구청)  184437  156541  94060  87179
# ..      ...  ...         ...          ...     ...     ...    ...    ...
# 422  202212  관악구         신림선     관악산(서울대)    3943    3190   2206   1810
# 423  202212  관악구         신림선           당곡   16140   12007   7024   6321
# 424  202212  관악구         신림선      서울대벤처타운   29370   23873  14981  14057
# 425  202212  관악구         신림선           서원   11009   10406   6573   6144
# 426  202212  관악구         신림선           신림   10378    6837   3779   3563
#
#      22-23  23-24  00-01  01-02  02-03  03-04  04-05
# ...

# %%
subway_group = subway.groupby(['month', 'area']).sum(); subway_group
# Out:
# <ipython-input-16-3eeefa3e9209>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   subway_group = subway.groupby(['month', 'area']).sum(); subway_group
#                18-19   19-20   20-21   21-22   22-23   23-24  00-01  01-02  \
# month  area
# 202212 강남구   1269443  780075  441946  398893  346778  204190  65108   4356
#        강서구    763937  594207  351796  322654  300223  197045  67904   2346
#        관악구    650498  566016  350287  337372  334298  216864  72212   6551
#        노원구    689293  606052  355646  322886  300443  211041  70805   3887
#        송파구   1064002  739614  444658  416893  399304  239929  70742   3274
# 202301 강남구   1096686  700185  394025  339075  295314  171098  52947   2905
#        강서구    714265  577892  329766  293491  262660  165127  55445   1408
# ...

# %%
subway_group.to_csv('/content/drive/MyDrive/BADA/바다톤/data/귀가시간대_지하철_하차인원_통합.csv')
