# %% [markdown]
# <a href="https://colab.research.google.com/github/seeedata/BADA/blob/main/BADATON/%EC%A7%80%ED%95%98%EC%B2%A0%20%EB%8D%B0%EC%9D%B4%ED%84%B0%20%EA%B7%80%EA%B0%80%EC%8B%9C%EA%B0%84%20%EC%A0%84%EC%B2%98%EB%A6%AC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Import

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# #데이터 전처리

# %% [markdown]
# ##22년 1~8호선

# %%
sub_22 = pd.read_csv('/content/drive/MyDrive/colab_data/서울교통공사_역별 일별 시간대별 승하차인원 정보_20221231 (2).csv', encoding = 'cp949')
sub_22.head()
# Out:
#    연번        수송일자  호선 고유역번호(외부역코드)   역명 승하차구분  06시이전  06-07시간대  07-08시간대  \
# 0   1  2022-01-01   1          150  서울역    승차    120       137       211
# 1   2  2022-01-01   1          150  서울역    하차    113       560       617
# 2   3  2022-01-01   1          151   시청    승차     38        66       101
# 3   4  2022-01-01   1          151   시청    하차     31       195       224
# 4   5  2022-01-01   1          152   종각    승차     44        71        86
#
#    08-09시간대  ...  15-16시간대  16-17시간대  17-18시간대  18-19시간대  19-20시간대  20-21시간대  \
# 0       439  ...      1566      1686      1591      1358      1062       899
# 1       910  ...      1329      1251      1126       884       764       654
# 2       139  ...       474       550       672       528       420       434
# 3       380  ...       408       377       354       213       131        98
# 4       158  ...       889       964      1024       803       855      1099
#
#    21-22시간대  22-23시간대  23-24시간대  24시이후
# ...

# %%
stations = [
            '잠실나루', '잠실(송파구청)', '잠실새내', '종합운동장', '가락시장', '경찰병원', '오금', '올림픽공원(한국체대)', '방이', '개롱', '거여', '마천', '몽촌토성(평화의문)', '석촌', '송파', '문정', '장지', '복정', '삼전', '석촌고분', '송파나루', '한성백제',
            '방화', '개화산', '김포공항', '송정', '마곡', '발산', '우장산', '화곡', '까치산', '개화', '공항시장', '신방화', '마곡나루(서울식물원)', '양천향교', '가양', '증미', '등촌',
            '삼성(무역센터)', '선릉', '역삼', '강남', '압구정', '신사', '매봉', '도곡', '대치', '학여울', '대청', '일원', '수서', '청담', '강남구청', '학동', '논현', '언주', '선정릉', '삼성중앙', '봉은사', '신논현', '압구정로데오', '한티', '구룡', '개포동', '대모산입구',
            '당고개', '상계', '노원', '석계', '태릉입구', '화랑대(서울여대입구)', '수락산', '마들', '중계', '하계', '공릉(서울과학기술대)', '월계', '광운대',
            '낙성대(강감찬)', '서울대입구(관악구청)', '봉천', '신림', '당곡', '서원', '서울대벤처타운', '관악산(서울대)'
            ]

# %%
sub_22 = sub_22.loc[sub_22['역명'].isin(stations)] ; sub_22
# Out:
#             연번        수송일자  호선 고유역번호(외부역코드)        역명 승하차구분  06시이전  06-07시간대  \
# 48          49  2022-01-01   2          215      잠실나루    승차     49        62
# 49          50  2022-01-01   2          215      잠실나루    하차     24       121
# 50          51  2022-01-01   2          216  잠실(송파구청)    승차    211       343
# 51          52  2022-01-01   2          216  잠실(송파구청)    하차     56       410
# 52          53  2022-01-01   2          217      잠실새내    승차     80       161
# ...        ...         ...  ..          ...       ...   ...    ...       ...
# 199061  199062  2022-12-31   8         2819        문정    하차     42       141
# 199062  199063  2022-12-31   8         2820        장지    승차    206       377
# 199063  199064  2022-12-31   8         2820        장지    하차     67       263
# 199064  199065  2022-12-31   8         2821        복정    승차    151       165
# 199065  199066  2022-12-31   8         2821        복정    하차     60       196
#
# ...

# %%
len(sub_22['역명'].unique())
# Out:
# 59

# %%
len(stations)
# Out:
# 87

# %%
sub_22.head()
# Out:
#     연번        수송일자  호선 고유역번호(외부역코드)        역명 승하차구분  06시이전  06-07시간대  \
# 48  49  2022-01-01   2          215      잠실나루    승차     49        62
# 49  50  2022-01-01   2          215      잠실나루    하차     24       121
# 50  51  2022-01-01   2          216  잠실(송파구청)    승차    211       343
# 51  52  2022-01-01   2          216  잠실(송파구청)    하차     56       410
# 52  53  2022-01-01   2          217      잠실새내    승차     80       161
#
#     07-08시간대  08-09시간대  ...  15-16시간대  16-17시간대  17-18시간대  18-19시간대  19-20시간대  \
# 48        94       158  ...       313       322       312       196       135
# 49       125       135  ...       226       280       316       237       204
# 50       391       639  ...      2807      3544      3571      3098      2664
# 51       558      1049  ...      3414      3252      2711      2207      1391
# 52       192       283  ...       622       684       623       522       412
#
#     20-21시간대  21-22시간대  22-23시간대  23-24시간대  24시이후
# ...

# %%
sub_22.drop('연번', axis = 1, inplace = True)
sub_22.columns = ['날짜', '호선', '역번호', '역명', '구분', '6시이전', '06~07', '07~08', '08~09', '09~10', '10~11', '11~12',
       '12~13', '13~14', '14~15', '15~16', '16~17', '17~18', '18~19', '19~20',
       '20~21', '21~22', '22~23', '23~24', '24시이후']
sub_22 = sub_22[['날짜', '호선', '역명', '구분', '18~19', '19~20', '20~21', '21~22', '22~23', '23~24', '24시이후', '6시이전']]
sub_22
# Out:
#                 날짜  호선        역명  구분  18~19  19~20  20~21  21~22  22~23  \
# 48      2022-01-01   2      잠실나루  승차    196    135    141    136     74
# 49      2022-01-01   2      잠실나루  하차    237    204    219    302    209
# 50      2022-01-01   2  잠실(송파구청)  승차   3098   2664   3296   4207   1456
# 51      2022-01-01   2  잠실(송파구청)  하차   2207   1391   1286   2080   1019
# 52      2022-01-01   2      잠실새내  승차    522    412    609    894    250
# ...            ...  ..       ...  ..    ...    ...    ...    ...    ...
# 199061  2022-12-31   8        문정  하차    432    357    259    319    274
# 199062  2022-12-31   8        장지  승차    924    721    598    639    356
# 199063  2022-12-31   8        장지  하차    792    551    411    511    400
# 199064  2022-12-31   8        복정  승차    315    241    206    389    132
# 199065  2022-12-31   8        복정  하차    485    374    236    322    266
#
#         23~24  24시이후  6시이전
# 48         25    NaN    49
# 49         93    NaN    24
# ...

# %%
sub_22 = sub_22.fillna(0)
sub_22
# Out:
#                 날짜  호선        역명  구분  18~19  19~20  20~21  21~22  22~23  \
# 48      2022-01-01   2      잠실나루  승차    196    135    141    136     74
# 49      2022-01-01   2      잠실나루  하차    237    204    219    302    209
# 50      2022-01-01   2  잠실(송파구청)  승차   3098   2664   3296   4207   1456
# 51      2022-01-01   2  잠실(송파구청)  하차   2207   1391   1286   2080   1019
# 52      2022-01-01   2      잠실새내  승차    522    412    609    894    250
# ...            ...  ..       ...  ..    ...    ...    ...    ...    ...
# 199061  2022-12-31   8        문정  하차    432    357    259    319    274
# 199062  2022-12-31   8        장지  승차    924    721    598    639    356
# 199063  2022-12-31   8        장지  하차    792    551    411    511    400
# 199064  2022-12-31   8        복정  승차    315    241    206    389    132
# 199065  2022-12-31   8        복정  하차    485    374    236    322    266
#
#         23~24  24시이후  6시이전
# 48         25    0.0    49
# 49         93    0.0    24
# ...

# %%
sub_22['24시이후'] = sub_22['24시이후'].astype('int64')

# %%
sub_22 = sub_22[(sub_22['날짜']>='2022-12-01')&(sub_22['날짜']<='2022-12-31')]; sub_22
# Out:
#                 날짜  호선        역명  구분  18~19  19~20  20~21  21~22  22~23  \
# 182206  2022-12-01   2      잠실나루  승차   1113    499    379    272    205
# 182207  2022-12-01   2      잠실나루  하차   1697   1020    687    658    705
# 182208  2022-12-01   2  잠실(송파구청)  승차   8332   5036   5257   4898   3397
# 182209  2022-12-01   2  잠실(송파구청)  하차   9663   5857   3391   3284   2856
# 182210  2022-12-01   2      잠실새내  승차   1494   1071    970    899    826
# ...            ...  ..       ...  ..    ...    ...    ...    ...    ...
# 199061  2022-12-31   8        문정  하차    432    357    259    319    274
# 199062  2022-12-31   8        장지  승차    924    721    598    639    356
# 199063  2022-12-31   8        장지  하차    792    551    411    511    400
# 199064  2022-12-31   8        복정  승차    315    241    206    389    132
# 199065  2022-12-31   8        복정  하차    485    374    236    322    266
#
#         23~24  24시이후  6시이전
# 182206     95     28   120
# 182207    327    122    61
# ...

# %%
sub_22 = sub_22[sub_22['구분']=='하차']; sub_22
# Out:
#                 날짜  호선        역명  구분  18~19  19~20  20~21  21~22  22~23  \
# 182207  2022-12-01   2      잠실나루  하차   1697   1020    687    658    705
# 182209  2022-12-01   2  잠실(송파구청)  하차   9663   5857   3391   3284   2856
# 182211  2022-12-01   2      잠실새내  하차   3457   2102   1244   1212   1045
# 182213  2022-12-01   2     종합운동장  하차   1173    750    373    434    366
# 182215  2022-12-01   2  삼성(무역센터)  하차   2732   1336    604    543    408
# ...            ...  ..       ...  ..    ...    ...    ...    ...    ...
# 199057  2022-12-31   8        송파  하차    452    352    322    277    284
# 199059  2022-12-31   8      가락시장  하차    385    299    224    183    158
# 199061  2022-12-31   8        문정  하차    432    357    259    319    274
# 199063  2022-12-31   8        장지  하차    792    551    411    511    400
# 199065  2022-12-31   8        복정  하차    485    374    236    322    266
#
#         23~24  24시이후  6시이전
# 182207    327    122    61
# 182209   1698    319   171
# ...

# %%
sub_22['역명'].value_counts()
# Out:
# 잠실(송파구청)       62
# 노원             62
# 오금             62
# 가락시장           62
# 태릉입구           62
# 잠실나루           31
# 화랑대(서울여대입구)    31
# 화곡             31
# 까치산            31
# 올림픽공원(한국체대)    31
# 방이             31
# 개롱             31
# 거여             31
# 마천             31
# 석계             31
# 수락산            31
# 발산             31
# 마들             31
# 중계             31
# 하계             31
# 공릉(서울과학기술대)    31
# 청담             31
# 강남구청           31
# 학동             31
# 논현             31
# 몽촌토성(평화의문)     31
# 석촌             31
# 송파             31
# 문정             31
# 장지             31
# 우장산            31
# 김포공항           31
# 마곡             31
# 신사             31
# 잠실새내           31
# 종합운동장          31
# 삼성(무역센터)       31
# 선릉             31
# 역삼             31
# 강남             31
# 낙성대(강감찬)       31
# 서울대입구(관악구청)    31
# 봉천             31
# 신림             31
# 압구정            31
# 매봉             31
# 송정             31
# 도곡             31
# 대치             31
# 학여울            31
# ...

# %% [markdown]
# ##23년 1~8호선

# %%
sub_23 = pd.read_csv('/content/drive/MyDrive/colab_data/서울교통공사_역별 일별 시간대별 승하차인원 정보_20230430 (1).csv', encoding='cp949')
sub_23.head()
# Out:
#    연번        수송일자   호선  역번호   역명 승하차구분  06시이전  06-07시간대  07-08시간대  08-09시간대  \
# 0   1  2023-01-01  1호선  150  서울역    승차    215       145       231       594
# 1   2  2023-01-01  1호선  150  서울역    하차    154       636       595       939
# 2   3  2023-01-01  1호선  151   시청    승차     48        73       106       194
# 3   4  2023-01-01  1호선  151   시청    하차     64       247       293       463
# 4   5  2023-01-01  1호선  152   종각    승차    407       235       158       201
#
#    ...  15-16시간대  16-17시간대  17-18시간대  18-19시간대  19-20시간대  20-21시간대  21-22시간대  \
# 0  ...      2655      2509      2696      2549      2462      2177      2190
# 1  ...      2282      2295      2526      1930      1897      1487       991
# 2  ...       843       895       959       985       670       630       515
# 3  ...       602       575       533       456       285       267       246
# 4  ...      1145      1402      1223      1272       911       913       906
#
#    22-23시간대  23-24시간대  24시이후
# ...

# %%
sub_23 = sub_23.loc[sub_23['역명'].isin(stations)] ; sub_23
# Out:
#           연번        수송일자   호선   역번호        역명 승하차구분  06시이전  06-07시간대  \
# 48        49  2023-01-01  2호선   215      잠실나루    승차     55        92
# 49        50  2023-01-01  2호선   215      잠실나루    하차     30       139
# 50        51  2023-01-01  2호선   216  잠실(송파구청)    승차    270       420
# 51        52  2023-01-01  2호선   216  잠실(송파구청)    하차    197       725
# 52        53  2023-01-01  2호선   217      잠실새내    승차    198       239
# ...      ...         ...  ...   ...       ...   ...    ...       ...
# 65266  65267  2023-04-30  8호선  2819        문정    하차     18       150
# 65267  65268  2023-04-30  8호선  2820        장지    승차     96       191
# 65268  65269  2023-04-30  8호선  2820        장지    하차     43       148
# 65269  65270  2023-04-30  8호선  2821        복정    승차     45       120
# 65270  65271  2023-04-30  8호선  2821        복정    하차     27       130
#
#        07-08시간대  08-09시간대  ...  15-16시간대  16-17시간대  17-18시간대  18-19시간대  \
# ...

# %%
sub_23.drop('연번', axis = 1, inplace = True)
sub_23.columns = ['날짜', '호선', '역번호', '역명', '구분', '6시이전', '06~07', '07~08', '08~09', '09~10', '10~11', '11~12',
       '12~13', '13~14', '14~15', '15~16', '16~17', '17~18', '18~19', '19~20',
       '20~21', '21~22', '22~23', '23~24', '24시이후']
sub_23 = sub_23[['날짜', '호선', '역명', '구분', '18~19', '19~20', '20~21', '21~22', '22~23', '23~24', '24시이후', '6시이전']]
sub_23
# Out:
#                날짜   호선        역명  구분  18~19  19~20  20~21  21~22  22~23  \
# 48     2023-01-01  2호선      잠실나루  승차    223    160    168    128     92
# 49     2023-01-01  2호선      잠실나루  하차    354    274    265    223    219
# 50     2023-01-01  2호선  잠실(송파구청)  승차   4317   3612   3635   3513   2317
# 51     2023-01-01  2호선  잠실(송파구청)  하차   2487   1973   1720   1511   1242
# 52     2023-01-01  2호선      잠실새내  승차    662    484    519    590    543
# ...           ...  ...       ...  ..    ...    ...    ...    ...    ...
# 65266  2023-04-30  8호선        문정  하차    429    392    412    401    281
# 65267  2023-04-30  8호선        장지  승차    794    607    617    574    278
# 65268  2023-04-30  8호선        장지  하차    868    634    501    480    413
# 65269  2023-04-30  8호선        복정  승차    307    230    222    194    126
# 65270  2023-04-30  8호선        복정  하차    391    306    333    295    223
#
#        23~24  24시이후  6시이전
# 48        35      0    55
# 49       160      1    30
# ...

# %%
sub_23.isna().sum()
# Out:
# 날짜       0
# 호선       0
# 역명       0
# 구분       0
# 18~19    0
# 19~20    0
# 20~21    0
# 21~22    0
# 22~23    0
# 23~24    0
# 24시이후    0
# 6시이전     0
# dtype: int64

# %%
sub_23 = sub_23[(sub_23['날짜']>='2023-01-01')&(sub_23['날짜']<='2023-03-31')]
sub_23 = sub_23[sub_23['구분']=='하차']; sub_23
sub_23
# Out:
#                날짜   호선        역명  구분  18~19  19~20  20~21  21~22  22~23  \
# 49     2023-01-01  2호선      잠실나루  하차    354    274    265    223    219
# 51     2023-01-01  2호선  잠실(송파구청)  하차   2487   1973   1720   1511   1242
# 53     2023-01-01  2호선      잠실새내  하차    903    753    591    595    518
# 55     2023-01-01  2호선     종합운동장  하차   1265    223    199    198    153
# 57     2023-01-01  2호선  삼성(무역센터)  하차    934    561    506    376    260
# ...           ...  ...       ...  ..    ...    ...    ...    ...    ...
# 48941  2023-03-31  8호선        송파  하차   1193    925    509    451    502
# 48943  2023-03-31  8호선      가락시장  하차    909    654    376    359    266
# 48945  2023-03-31  8호선        문정  하차   1635   1011    574    460    478
# 48947  2023-03-31  8호선        장지  하차   2132   1470    850    696    865
# 48949  2023-03-31  8호선        복정  하차   1218    881    585    450    468
#
#        23~24  24시이후  6시이전
# 49       160      1    30
# 51       624      0   197
# ...

# %%
sub_23.역명.value_counts()
# Out:
# 잠실(송파구청)       180
# 노원             180
# 오금             180
# 가락시장           180
# 태릉입구           180
# 잠실나루            90
# 화랑대(서울여대입구)     90
# 화곡              90
# 까치산             90
# 올림픽공원(한국체대)     90
# 방이              90
# 개롱              90
# 거여              90
# 마천              90
# 석계              90
# 수락산             90
# 발산              90
# 마들              90
# 중계              90
# 하계              90
# 공릉(서울과학기술대)     90
# 청담              90
# 강남구청            90
# 학동              90
# 논현              90
# 몽촌토성(평화의문)      90
# 석촌              90
# 송파              90
# 문정              90
# 장지              90
# 우장산             90
# 김포공항            90
# 마곡              90
# 신사              90
# 잠실새내            90
# 종합운동장           90
# 삼성(무역센터)        90
# 선릉              90
# 역삼              90
# 강남              90
# 낙성대(강감찬)        90
# 서울대입구(관악구청)     90
# 봉천              90
# 신림              90
# 압구정             90
# 매봉              90
# 송정              90
# ...

# %% [markdown]
# ##22년 9호선 2~3단계

# %%
sub_22_9 = pd.read_csv('/content/drive/MyDrive/colab_data/서울교통공사_9호선2_3단계 역별일별시간대별승하차인원_20221231.csv', encoding='cp949')
sub_22_9.head()
# Out:
#    연번        수송일자  호선  고유역번호(외부역코드)  역명 승하차구분  00-01시간대  01-02시간대  02-03시간대  \
# 0   1  2022-01-01   9          4126  언주   순승차         0         0         0
# 1   2  2022-01-01   9          4126  언주   순하차         2         0         0
# 2   3  2022-01-02   9          4126  언주   순승차         0         0         0
# 3   4  2022-01-02   9          4126  언주   순하차         3         0         0
# 4   5  2022-01-03   9          4126  언주   순승차         0         0         0
#
#    03-04시간대  ...  14-15시간대  15-16시간대  16-17시간대  17-18시간대  18-19시간대  19-20시간대  \
# 0         0  ...       218       164       162       168       106        99
# 1         0  ...       140       159       135       188       146       105
# 2         0  ...       218       244       275       250       197       168
# 3         0  ...       210       228       191       218       178       140
# 4         0  ...       422       474       633      1544      2549      1168
#
#    20-21시간대  21-22시간대  22-23시간대  23-24시간대
# ...

# %%
sub_22_9 = sub_22_9.loc[sub_22_9['역명'].isin(stations)] ; sub_22_9
# Out:
#         연번        수송일자  호선  고유역번호(외부역코드)    역명 승하차구분  00-01시간대  01-02시간대  \
# 0        1  2022-01-01   9          4126    언주   순승차         0         0
# 1        2  2022-01-01   9          4126    언주   순하차         2         0
# 2        3  2022-01-02   9          4126    언주   순승차         0         0
# 3        4  2022-01-02   9          4126    언주   순하차         3         0
# 4        5  2022-01-03   9          4126    언주   순승차         0         0
# ...    ...         ...  ..           ...   ...   ...       ...       ...
# 7295  7296  2022-12-29   9          4135  한성백제   순하차        51         0
# 7296  7297  2022-12-30   9          4135  한성백제   순승차         5         0
# 7297  7298  2022-12-30   9          4135  한성백제   순하차        46         0
# 7298  7299  2022-12-31   9          4135  한성백제   순승차         7        10
# 7299  7300  2022-12-31   9          4135  한성백제   순하차        14         6
#
#       02-03시간대  03-04시간대  ...  14-15시간대  15-16시간대  16-17시간대  17-18시간대  \
# ...

# %%
sub_22_9.drop('연번', axis = 1, inplace = True)
sub_22_9.columns = ['날짜', '호선', '역번호', '역명', '구분', '00~01', '01~02', '02~03', '03~04',
       '04~05', '05~06', '06~07', '07~08', '08~09', '09~10', '10~11', '11~12',
       '12~13', '13~14', '14~15', '15~16', '16~17', '17~18', '18~19', '19~20',
       '20~21', '21~22', '22~23', '23~24']
sub_22_9 = sub_22_9[['날짜', '호선', '역명', '구분', '18~19', '19~20', '20~21', '21~22', '22~23', '23~24', '00~01', '01~02', '02~03', '03~04', '04~05', '05~06']]
sub_22_9
# Out:
#               날짜  호선    역명   구분  18~19  19~20  20~21  21~22  22~23  23~24  \
# 0     2022-01-01   9    언주  순승차    106     99    117    117     72     17
# 1     2022-01-01   9    언주  순하차    146    105     99    170     84     30
# 2     2022-01-02   9    언주  순승차    197    168    130    143     86     22
# 3     2022-01-02   9    언주  순하차    178    140    165    211    120     48
# 4     2022-01-03   9    언주  순승차   2549   1168    603    480    218     48
# ...          ...  ..   ...  ...    ...    ...    ...    ...    ...    ...
# 7295  2022-12-29   9  한성백제  순하차    265    206    127     99    128     78
# 7296  2022-12-30   9  한성백제  순승차    213    116    103     75     67     30
# 7297  2022-12-30   9  한성백제  순하차    199    137     99    109     98     89
# 7298  2022-12-31   9  한성백제  순승차    120     86     76     76     47     20
# 7299  2022-12-31   9  한성백제  순하차     78     90     67     84     85     53
#
#       00~01  01~02  02~03  03~04  04~05  05~06
# ...

# %%
sub_22_9.isna().sum()
# Out:
# 날짜       0
# 호선       0
# 역명       0
# 구분       0
# 18~19    0
# 19~20    0
# 20~21    0
# 21~22    0
# 22~23    0
# 23~24    0
# 00~01    0
# 01~02    0
# 02~03    0
# 03~04    0
# 04~05    0
# 05~06    0
# dtype: int64

# %%
sub_22_9.구분.unique()
# Out:
# array(['순승차', '순하차'], dtype=object)

# %%
sub_22_9 = sub_22_9[(sub_22_9['날짜']>='2022-12-01')&(sub_22_9['날짜']<='2022-12-31')]
sub_22_9 = sub_22_9[sub_22_9['구분']=='순하차']
sub_22_9
# Out:
#               날짜  호선    역명   구분  18~19  19~20  20~21  21~22  22~23  23~24  \
# 669   2022-12-01   9    언주  순하차    560    479    246    231    181    112
# 671   2022-12-02   9    언주  순하차    752    506    266    236    187    147
# 673   2022-12-03   9    언주  순하차    446    197    206    230    164    118
# 675   2022-12-04   9    언주  순하차    218    190    165    165    126     82
# 677   2022-12-05   9    언주  순하차    578    456    239    240    165    103
# ...          ...  ..   ...  ...    ...    ...    ...    ...    ...    ...
# 7291  2022-12-27   9  한성백제  순하차    314    222    126    118    116     72
# 7293  2022-12-28   9  한성백제  순하차    298    205    125    111    134     84
# 7295  2022-12-29   9  한성백제  순하차    265    206    127     99    128     78
# 7297  2022-12-30   9  한성백제  순하차    199    137     99    109     98     89
# 7299  2022-12-31   9  한성백제  순하차     78     90     67     84     85     53
#
#       00~01  01~02  02~03  03~04  04~05  05~06
# ...

# %%
sub_22_9.역명.value_counts()
# Out:
# 언주       31
# 선정릉      31
# 삼성중앙     31
# 봉은사      31
# 종합운동장    31
# 삼전       31
# 석촌고분     31
# 석촌       31
# 송파나루     31
# 한성백제     31
# Name: 역명, dtype: int64

# %% [markdown]
# ##23년 9호선 2~3단계

# %%
sub_23_9 = pd.read_csv('/content/drive/MyDrive/colab_data/서울교통공사_9호선 2_3단계 역별일별시간대별승하차인원_20230531.csv', encoding = 'cp949')
sub_23_9.head()
# Out:
#    연번        수송일자  호선   역번호  역명 승하차구분  00-01시간대  01-02시간대  02-03시간대  03-04시간대  \
# 0   1  2023-01-01   9  4126  언주   순승차         0         0         0         0
# 1   2  2023-01-01   9  4126  언주   순하차         7         0         0         0
# 2   3  2023-01-02   9  4126  언주   순승차        23         0         0         0
# 3   4  2023-01-02   9  4126  언주   순하차        41         3         0         0
# 4   5  2023-01-03   9  4126  언주   순승차        17         0         0         0
#
#    ...  14-15시간대  15-16시간대  16-17시간대  17-18시간대  18-19시간대  19-20시간대  20-21시간대  \
# 0  ...       170       215       220       166       136       118        93
# 1  ...       154       170       154       180       148       146       176
# 2  ...       376       512       766      1706      2732      1216       547
# 3  ...       296       344       278       389       502       416       235
# 4  ...       420       567       777      1758      2747      1279       664
#
#    21-22시간대  22-23시간대  23-24시간대
# ...

# %%
sub_23_9 = sub_23_9.loc[sub_23_9['역명'].isin(stations)]
sub_23_9.drop('연번', axis = 1, inplace = True)
sub_23_9.columns = ['날짜', '호선', '역번호', '역명', '구분', '00~01', '01~02', '02~03', '03~04',
       '04~05', '05~06', '06~07', '07~08', '08~09', '09~10', '10~11', '11~12',
       '12~13', '13~14', '14~15', '15~16', '16~17', '17~18', '18~19', '19~20',
       '20~21', '21~22', '22~23', '23~24']
sub_23_9 = sub_23_9[['날짜', '호선', '역명', '구분', '18~19', '19~20', '20~21', '21~22', '22~23', '23~24', '00~01', '01~02', '02~03', '03~04', '04~05', '05~06']]
sub_23_9
# Out:
#               날짜  호선    역명   구분  18~19  19~20  20~21  21~22  22~23  23~24  \
# 0     2023-01-01   9    언주  순승차    136    118     93     98     91     21
# 1     2023-01-01   9    언주  순하차    148    146    176    173    113     84
# 2     2023-01-02   9    언주  순승차   2732   1216    547    457    340    106
# 3     2023-01-02   9    언주  순하차    502    416    235    213    151     80
# 4     2023-01-03   9    언주  순승차   2747   1279    664    525    367    130
# ...          ...  ..   ...  ...    ...    ...    ...    ...    ...    ...
# 3735  2023-05-29   9  한성백제  순하차     97     99     96     71     68     46
# 3736  2023-05-30   9  한성백제  순승차    312    123     83     67     53     22
# 3737  2023-05-30   9  한성백제  순하차    345    253    168    123    126     61
# 3738  2023-05-31   9  한성백제  순승차    312    110    123    108     52     29
# 3739  2023-05-31   9  한성백제  순하차    308    316    127    110    128     87
#
#       00~01  01~02  02~03  03~04  04~05  05~06
# ...

# %%
sub_23_9.isna().sum()
# Out:
# 날짜       0
# 호선       0
# 역명       0
# 구분       0
# 18~19    0
# 19~20    0
# 20~21    0
# 21~22    0
# 22~23    0
# 23~24    0
# 00~01    0
# 01~02    0
# 02~03    0
# 03~04    0
# 04~05    0
# 05~06    0
# dtype: int64

# %%
sub_23_9.구분.unique()
# Out:
# array(['순승차', '순하차'], dtype=object)

# %%
sub_23_9 = sub_23_9[(sub_23_9['날짜']>='2023-01-01')&(sub_23_9['날짜']<='2023-03-31')]
sub_23_9 = sub_23_9[sub_23_9['구분']=='순하차']
sub_23_9
# Out:
#               날짜  호선    역명   구분  18~19  19~20  20~21  21~22  22~23  23~24  \
# 1     2023-01-01   9    언주  순하차    148    146    176    173    113     84
# 3     2023-01-02   9    언주  순하차    502    416    235    213    151     80
# 5     2023-01-03   9    언주  순하차    552    443    241    240    166     86
# 7     2023-01-04   9    언주  순하차    617    439    256    184    156     95
# 9     2023-01-05   9    언주  순하차    606    441    259    235    146    112
# ...          ...  ..   ...  ...    ...    ...    ...    ...    ...    ...
# 2331  2023-03-27   9  한성백제  순하차    348    286    142    118    106     57
# 2333  2023-03-28   9  한성백제  순하차    321    281    149    125    126     90
# 2335  2023-03-29   9  한성백제  순하차    322    266    147    142    129     75
# 2337  2023-03-30   9  한성백제  순하차    372    262    163    133    126     87
# 2339  2023-03-31   9  한성백제  순하차    322    279    143    124    129     98
#
#       00~01  01~02  02~03  03~04  04~05  05~06
# ...

# %%
sub_23_9.역명.value_counts()
# Out:
# 언주       90
# 선정릉      90
# 삼성중앙     90
# 봉은사      90
# 종합운동장    90
# 삼전       90
# 석촌고분     90
# 석촌       90
# 송파나루     90
# 한성백제     90
# Name: 역명, dtype: int64

# %% [markdown]
# 9호선 1단계는 데이터가 없다ㅠㅠ

# %% [markdown]
# #데이터 통합

# %% [markdown]
# ##1~8호선 데이터 통합

# %%
sub1 = pd.concat([sub_22, sub_23], axis=0); sub1
# Out:
#                 날짜   호선        역명  구분  18~19  19~20  20~21  21~22  22~23  \
# 182207  2022-12-01    2      잠실나루  하차   1697   1020    687    658    705
# 182209  2022-12-01    2  잠실(송파구청)  하차   9663   5857   3391   3284   2856
# 182211  2022-12-01    2      잠실새내  하차   3457   2102   1244   1212   1045
# 182213  2022-12-01    2     종합운동장  하차   1173    750    373    434    366
# 182215  2022-12-01    2  삼성(무역센터)  하차   2732   1336    604    543    408
# ...            ...  ...       ...  ..    ...    ...    ...    ...    ...
# 48941   2023-03-31  8호선        송파  하차   1193    925    509    451    502
# 48943   2023-03-31  8호선      가락시장  하차    909    654    376    359    266
# 48945   2023-03-31  8호선        문정  하차   1635   1011    574    460    478
# 48947   2023-03-31  8호선        장지  하차   2132   1470    850    696    865
# 48949   2023-03-31  8호선        복정  하차   1218    881    585    450    468
#
#         23~24  24시이후  6시이전
# 182207    327    122    61
# 182209   1698    319   171
# ...

# %%
pd.DataFrame(sub1['날짜'].value_counts())
# Out:
#             날짜
# 2022-12-01  64
# 2023-01-31  64
# 2023-02-28  64
# 2023-02-27  64
# 2023-02-26  64
# ...         ..
# 2023-01-06  64
# 2023-01-05  64
# 2023-01-04  64
# 2023-01-03  64
# 2023-03-31  64
#
# [121 rows x 1 columns]

# %%
sub1['count'] = sub1['18~19']+sub1['19~20']+sub1['20~21']+sub1['21~22']+sub1['22~23']+sub1['23~24']+sub1['24시이후']+sub1['6시이전']; sub1
# Out:
#                 날짜   호선        역명  구분  18~19  19~20  20~21  21~22  22~23  \
# 182207  2022-12-01    2      잠실나루  하차   1697   1020    687    658    705
# 182209  2022-12-01    2  잠실(송파구청)  하차   9663   5857   3391   3284   2856
# 182211  2022-12-01    2      잠실새내  하차   3457   2102   1244   1212   1045
# 182213  2022-12-01    2     종합운동장  하차   1173    750    373    434    366
# 182215  2022-12-01    2  삼성(무역센터)  하차   2732   1336    604    543    408
# ...            ...  ...       ...  ..    ...    ...    ...    ...    ...
# 48941   2023-03-31  8호선        송파  하차   1193    925    509    451    502
# 48943   2023-03-31  8호선      가락시장  하차    909    654    376    359    266
# 48945   2023-03-31  8호선        문정  하차   1635   1011    574    460    478
# 48947   2023-03-31  8호선        장지  하차   2132   1470    850    696    865
# 48949   2023-03-31  8호선        복정  하차   1218    881    585    450    468
#
#         23~24  24시이후  6시이전  count
# 182207    327    122    61   5277
# ...

# %%
sub1 = sub1[['날짜', '역명', 'count']]; sub1
# Out:
#                 날짜        역명  count
# 182207  2022-12-01      잠실나루   5277
# 182209  2022-12-01  잠실(송파구청)  27239
# 182211  2022-12-01      잠실새내   9906
# 182213  2022-12-01     종합운동장   3422
# 182215  2022-12-01  삼성(무역센터)   6224
# ...            ...       ...    ...
# 48941   2023-03-31        송파   4050
# 48943   2023-03-31      가락시장   3005
# 48945   2023-03-31        문정   4842
# 48947   2023-03-31        장지   6788
# 48949   2023-03-31        복정   4010
#
# [7744 rows x 3 columns]

# %% [markdown]
# ## 9호선 데이터 통합

# %%
sub2 = pd.concat([sub_22_9, sub_23_9], axis=0); sub2
# Out:
#               날짜  호선    역명   구분  18~19  19~20  20~21  21~22  22~23  23~24  \
# 669   2022-12-01   9    언주  순하차    560    479    246    231    181    112
# 671   2022-12-02   9    언주  순하차    752    506    266    236    187    147
# 673   2022-12-03   9    언주  순하차    446    197    206    230    164    118
# 675   2022-12-04   9    언주  순하차    218    190    165    165    126     82
# 677   2022-12-05   9    언주  순하차    578    456    239    240    165    103
# ...          ...  ..   ...  ...    ...    ...    ...    ...    ...    ...
# 2331  2023-03-27   9  한성백제  순하차    348    286    142    118    106     57
# 2333  2023-03-28   9  한성백제  순하차    321    281    149    125    126     90
# 2335  2023-03-29   9  한성백제  순하차    322    266    147    142    129     75
# 2337  2023-03-30   9  한성백제  순하차    372    262    163    133    126     87
# 2339  2023-03-31   9  한성백제  순하차    322    279    143    124    129     98
#
#       00~01  01~02  02~03  03~04  04~05  05~06
# ...

# %%
pd.DataFrame(sub2['날짜'].value_counts())
# Out:
#             날짜
# 2022-12-12  20
# 2023-03-22  20
# 2022-12-01  10
# 2023-02-15  10
# 2023-02-27  10
# ...         ..
# 2023-01-07  10
# 2023-01-06  10
# 2023-01-05  10
# 2023-01-04  10
# 2023-03-31  10
#
# [119 rows x 1 columns]

# %%
sub2[sub2.duplicated(subset=['날짜', '호선', '역명', '구분'])]  #중복값이 있다.
# Out:
#               날짜  호선     역명   구분  18~19  19~20  20~21  21~22  22~23  23~24  \
# 691   2022-12-12   9     언주  순하차    567    414    244    221    176     94
# 1421  2022-12-12   9    선정릉  순하차    502    421    236    196    182    113
# 2151  2022-12-12   9   삼성중앙  순하차    632    375    166    151    120     83
# 2881  2022-12-12   9    봉은사  순하차    912    568    281    247    185     75
# 3611  2022-12-12   9  종합운동장  순하차    602    437    228    233    165    116
# 4341  2022-12-12   9     삼전  순하차   1225    900    549    438    369    178
# 5071  2022-12-12   9   석촌고분  순하차    989    896    457    377    336    161
# 5801  2022-12-12   9     석촌  순하차   1167    977    486    414    433    208
# 6531  2022-12-12   9   송파나루  순하차    894    688    254    239    207    125
# 7261  2022-12-12   9   한성백제  순하차    363    311    157    123     99     62
# 161   2023-03-22   9     언주  순하차    561    419    245    225    162    135
# ...

# %%
sub2 = sub2[~sub2.duplicated(subset=['날짜', '호선', '역명', '구분'])]

# %%
pd.DataFrame(sub2['날짜'].value_counts())
# Out:
#             날짜
# 2022-12-01  10
# 2023-02-15  10
# 2023-02-27  10
# 2023-02-26  10
# 2023-02-25  10
# ...         ..
# 2023-01-06  10
# 2023-01-05  10
# 2023-01-04  10
# 2023-01-03  10
# 2023-03-31  10
#
# [119 rows x 1 columns]

# %%
sub2.columns
# Out:
# Index(['날짜', '호선', '역명', '구분', '18~19', '19~20', '20~21', '21~22', '22~23',
#        '23~24', '00~01', '01~02', '02~03', '03~04', '04~05', '05~06'],
#       dtype='object')

# %%
sub2['count'] = sub2['18~19']+sub2['19~20']+sub2['20~21']+sub2['21~22']+sub2['22~23']+sub2['23~24']+sub2['00~01']+sub2['01~02']+sub2['02~03']+sub2['03~04']+sub2['04~05']+sub2['05~06']; sub2
# Out:
#               날짜  호선    역명   구분  18~19  19~20  20~21  21~22  22~23  23~24  \
# 669   2022-12-01   9    언주  순하차    560    479    246    231    181    112
# 671   2022-12-02   9    언주  순하차    752    506    266    236    187    147
# 673   2022-12-03   9    언주  순하차    446    197    206    230    164    118
# 675   2022-12-04   9    언주  순하차    218    190    165    165    126     82
# 677   2022-12-05   9    언주  순하차    578    456    239    240    165    103
# ...          ...  ..   ...  ...    ...    ...    ...    ...    ...    ...
# 2331  2023-03-27   9  한성백제  순하차    348    286    142    118    106     57
# 2333  2023-03-28   9  한성백제  순하차    321    281    149    125    126     90
# 2335  2023-03-29   9  한성백제  순하차    322    266    147    142    129     75
# 2337  2023-03-30   9  한성백제  순하차    372    262    163    133    126     87
# 2339  2023-03-31   9  한성백제  순하차    322    279    143    124    129     98
#
#       00~01  01~02  02~03  03~04  04~05  05~06  count
# ...

# %%
sub2 = sub2[['날짜', '역명', 'count']]; sub2
# Out:
#               날짜    역명  count
# 669   2022-12-01    언주   1897
# 671   2022-12-02    언주   2222
# 673   2022-12-03    언주   1408
# 675   2022-12-04    언주    963
# 677   2022-12-05    언주   1872
# ...          ...   ...    ...
# 2331  2023-03-27  한성백제   1094
# 2333  2023-03-28  한성백제   1126
# 2335  2023-03-29  한성백제   1126
# 2337  2023-03-30  한성백제   1180
# 2339  2023-03-31  한성백제   1163
#
# [1190 rows x 3 columns]

# %%
sub = pd.concat([sub1, sub2], axis = 0)
sub
# Out:
#                 날짜        역명  count
# 182207  2022-12-01      잠실나루   5277
# 182209  2022-12-01  잠실(송파구청)  27239
# 182211  2022-12-01      잠실새내   9906
# 182213  2022-12-01     종합운동장   3422
# 182215  2022-12-01  삼성(무역센터)   6224
# ...            ...       ...    ...
# 2331    2023-03-27      한성백제   1094
# 2333    2023-03-28      한성백제   1126
# 2335    2023-03-29      한성백제   1126
# 2337    2023-03-30      한성백제   1180
# 2339    2023-03-31      한성백제   1163
#
# [8934 rows x 3 columns]

# %%
stations_송파 = ['잠실나루', '잠실(송파구청)', '잠실새내', '종합운동장', '가락시장', '경찰병원', '오금', '올림픽공원(한국체대)', '방이', '개롱', '거여', '마천', '몽촌토성(평화의문)', '석촌', '송파', '문정', '장지', '복정', '삼전', '석촌고분', '송파나루', '한성백제']
stations_강서 = ['방화', '개화산', '김포공항', '송정', '마곡', '발산', '우장산', '화곡', '까치산', '개화', '공항시장', '신방화', '마곡나루(서울식물원)', '양천향교', '가양', '증미', '등촌']
stations_강남 = ['삼성(무역센터)', '선릉', '역삼', '강남', '압구정', '신사', '매봉', '도곡', '대치', '학여울', '대청', '일원', '수서', '청담', '강남구청', '학동', '논현', '언주', '선정릉', '삼성중앙', '봉은사', '신논현', '압구정로데오', '한티', '구룡', '개포동', '대모산입구']
stations_노원 = ['당고개', '상계', '노원', '석계', '태릉입구', '화랑대(서울여대입구)', '수락산', '마들', '중계', '하계', '공릉(서울과학기술대)', '월계', '광운대']
stations_관악 = ['낙성대(강감찬)', '서울대입구(관악구청)', '봉천', '신림', '당곡', '서원', '서울대벤처타운', '관악산(서울대)']

# %%
sub.loc[sub['역명'].isin(stations_송파), 'area'] = '송파구'
sub.loc[sub['역명'].isin(stations_강서), 'area'] = '강서구'
sub.loc[sub['역명'].isin(stations_강남), 'area'] = '강남구'
sub.loc[sub['역명'].isin(stations_노원), 'area'] = '노원구'
sub.loc[sub['역명'].isin(stations_관악), 'area'] = '관악구'
sub
# Out:
#                 날짜        역명  count area
# 182207  2022-12-01      잠실나루   5277  송파구
# 182209  2022-12-01  잠실(송파구청)  27239  송파구
# 182211  2022-12-01      잠실새내   9906  송파구
# 182213  2022-12-01     종합운동장   3422  송파구
# 182215  2022-12-01  삼성(무역센터)   6224  강남구
# ...            ...       ...    ...  ...
# 2331    2023-03-27      한성백제   1094  송파구
# 2333    2023-03-28      한성백제   1126  송파구
# 2335    2023-03-29      한성백제   1126  송파구
# 2337    2023-03-30      한성백제   1180  송파구
# 2339    2023-03-31      한성백제   1163  송파구
#
# [8934 rows x 4 columns]

# %%
sub['역명'].unique()
# Out:
# array(['잠실나루', '잠실(송파구청)', '잠실새내', '종합운동장', '삼성(무역센터)', '선릉', '역삼', '강남',
#        '낙성대(강감찬)', '서울대입구(관악구청)', '봉천', '신림', '압구정', '신사', '매봉', '도곡',
#        '대치', '학여울', '대청', '일원', '수서', '가락시장', '경찰병원', '오금', '당고개', '상계',
#        '노원', '방화', '개화산', '김포공항', '송정', '마곡', '발산', '우장산', '화곡', '까치산',
#        '올림픽공원(한국체대)', '방이', '개롱', '거여', '마천', '석계', '태릉입구', '화랑대(서울여대입구)',
#        '수락산', '마들', '중계', '하계', '공릉(서울과학기술대)', '청담', '강남구청', '학동', '논현',
#        '몽촌토성(평화의문)', '석촌', '송파', '문정', '장지', '복정', '언주', '선정릉', '삼성중앙',
#        '봉은사', '삼전', '석촌고분', '송파나루', '한성백제'], dtype=object)

# %%
sub = sub.reset_index(drop=True)
sub['날짜'] = sub['날짜'].astype(str)
sub['날짜'] = pd.to_datetime(sub['날짜']); sub
# Out:
#              날짜        역명  count area
# 0    2022-12-01      잠실나루   5277  송파구
# 1    2022-12-01  잠실(송파구청)  27239  송파구
# 2    2022-12-01      잠실새내   9906  송파구
# 3    2022-12-01     종합운동장   3422  송파구
# 4    2022-12-01  삼성(무역센터)   6224  강남구
# ...         ...       ...    ...  ...
# 8929 2023-03-27      한성백제   1094  송파구
# 8930 2023-03-28      한성백제   1126  송파구
# 8931 2023-03-29      한성백제   1126  송파구
# 8932 2023-03-30      한성백제   1180  송파구
# 8933 2023-03-31      한성백제   1163  송파구
#
# [8934 rows x 4 columns]

# %%
sub.rename(columns = {'날짜': 'date'}, inplace=True); sub
# Out:
#            date        역명  count area
# 0    2022-12-01      잠실나루   5277  송파구
# 1    2022-12-01  잠실(송파구청)  27239  송파구
# 2    2022-12-01      잠실새내   9906  송파구
# 3    2022-12-01     종합운동장   3422  송파구
# 4    2022-12-01  삼성(무역센터)   6224  강남구
# ...         ...       ...    ...  ...
# 8929 2023-03-27      한성백제   1094  송파구
# 8930 2023-03-28      한성백제   1126  송파구
# 8931 2023-03-29      한성백제   1126  송파구
# 8932 2023-03-30      한성백제   1180  송파구
# 8933 2023-03-31      한성백제   1163  송파구
#
# [8934 rows x 4 columns]

# %%
sub = pd.DataFrame(sub.groupby(['area','date']).sum()['count']); sub
# Out:
#                   count
# area date
# 강남구  2022-12-01   89537
#      2022-12-02  105567
#      2022-12-03   63954
#      2022-12-04   41568
#      2022-12-05   81236
# ...                 ...
# 송파구  2023-03-27  123592
#      2023-03-28  128811
#      2023-03-29  132763
#      2023-03-30  134163
#      2023-03-31  140945
#
# [605 rows x 1 columns]

# %%
sub = sub.reset_index(level=0); sub
# Out:
#            area   count
# date
# 2022-12-01  강남구   89537
# 2022-12-02  강남구  105567
# 2022-12-03  강남구   63954
# 2022-12-04  강남구   41568
# 2022-12-05  강남구   81236
# ...         ...     ...
# 2023-03-27  송파구  123592
# 2023-03-28  송파구  128811
# 2023-03-29  송파구  132763
# 2023-03-30  송파구  134163
# 2023-03-31  송파구  140945
#
# [605 rows x 2 columns]

# %%
sub.to_csv('/content/drive/MyDrive/BADA/바다톤/data/8.7_지하철_귀가시간대_데이터통합.csv')
