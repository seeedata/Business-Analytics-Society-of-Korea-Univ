# %% [markdown]
# <a href="https://colab.research.google.com/github/seeedata/BADA/blob/main/%EC%84%B8%EC%85%983_23_%EB%8F%84%EC%A0%84%EA%B3%BC%EC%A0%9C_%EC%9D%B4%EC%84%B8%EC%9D%80.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

# %%
px = 0
py = 0

x = [2, 5, 8, 14, 17]
y = [6, 15, 12, 6, 3]

a = [2, 5, 7, 8, 12]
b = [2, 5, 7, 3, 12]

s1 = [79 ** 2, 235 ** 2, 155 ** 2, 79 ** 2, 155 ** 2]
s2 = [210 ** 2, 440 ** 2, 210 ** 2, 440 ** 2, 440 ** 2]
s3 = [60 ** 2]

i = 0
j = 0

while True:
    plt.figure(figsize = (20, 20))
    plt.scatter(x, y, s = s1, color = 'blue', marker = 'D', alpha = 0.2)
    plt.scatter(a, b, s = s2, color = 'red', marker = '.', alpha = 0.2)
    plt.scatter(px, py, s = s3, color = 'green', marker = '*')
    plt.xlim(0, 20)
    plt.ylim(0, 20)
    plt.xticks(range(0,21))
    plt.yticks(range(0,21))
    plt.style.use('ggplot')
    plt.show()

    if (px not in range(0,21) or py not in range(0,21)):
        print('산책 끝','\n','코코의 기분이 %d 좋아졌습니다!' %j)
        break

    if ((px == 1 and py == 2) or
    (px == 2 and py in range(1,4)) or
    (px == 3 and (py == 2 or py in range(4,6))) or
    (px == 4 and py in range(3,8)) or
    (px == 5 and py in range(3,8)) or
    (px == 6 and py in range(2,9)) or
    (px == 7 and py in range(1,9)) or
    (px == 8 and py in range(1,9)) or
    (px == 9 and py in range(1,5)) or
    (px == 10 and (py in range(2,5) or py in range(11,14))) or
    (px == 11 and py in range(10,15)) or
    (px == 12 and py in range(10,15)) or
    (px == 13 and py in range(10,15)) or
    (px == 14 and py in range(11,14))):
        i = i + 1
        if i >= 3:
            print('코코의 기분이 좋지 않아 보입니다.','\n','산책 끝','\n','코코의 기분이 %d 좋아졌습니다!' %j)
            break
        else:
            print('코코의 기분이 좋지 않아 보입니다.')

    if ((px == 1 and py == 6) or
    (px == 2 and (py in range(5,8) or py == 15)) or
    (px == 3 and (py == 6 or py in range(14,17))) or
    (px == 4 and py in range(13,18)) or
    (px == 5 and py in range(12,19)) or
    (px == 6 and py in range(12,18)) or
    (px == 7 and py in range(11,17)) or
    (px == 8 and py in range(10,16)) or
    (px == 9 and py in range(11,14)) or
    (px == 13 and py == 6) or
    (px == 14 and py in range(5,8)) or
    (px == 15 and (py == 3 or py == 6)) or
    (px == 16 and py in range(2,5)) or
    (px == 17 and py in range(1,6)) or
    (px == 18 and py in range(2,5)) or
    (px == 19 and py == 3)):
        j = j + 1
        print('코코가 매우 기뻐합니다!')

    move = input('enter W(w), A(a), S(s), or D(d): ')
    if move == 'W' or move == 'w':
        px = px
        py = py + 1
    elif move == 'A' or move == 'a':
        px = px - 1
        py = py
    elif move == 'S' or move == 's':
        px = px
        py = py - 1
    elif move == 'D' or move == 'd':
        px = px + 1
        py = py
    else:
        px = px
        py = py
# Out:
# enter W(w), A(a), S(s), or D(d): w
# enter W(w), A(a), S(s), or D(d): d
# enter W(w), A(a), S(s), or D(d): e
# enter W(w), A(a), S(s), or D(d): w
# 코코의 기분이 좋지 않아 보입니다.
# enter W(w), A(a), S(s), or D(d): w
# enter W(w), A(a), S(s), or D(d): w
# enter W(w), A(a), S(s), or D(d): d
# enter W(w), A(a), S(s), or D(d): w
# 코코가 매우 기뻐합니다!
# enter W(w), A(a), S(s), or D(d): a
# enter W(w), A(a), S(s), or D(d): a
# enter W(w), A(a), S(s), or D(d): a
# 산책 끝
#  코코의 기분이 1 좋아졌습니다!
