# %% [markdown]
# <a href="https://colab.research.google.com/github/seeedata/BADA/blob/main/%EB%8C%80%ED%95%99%EC%9B%90%20%ED%94%84%EB%A1%9C%EC%A0%9D%ED%8A%B8%20%ED%81%AC%EB%A1%A4%EB%A7%81%20%EB%B3%B4%EC%A1%B0/%EC%98%81%ED%99%94%20%EC%A0%95%EB%B3%B4%20%EC%B5%9C%EC%A2%85%20%ED%8C%8C%EC%9D%BC%20%EC%A0%9C%EC%9E%91.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("C:/Users/이세은/Desktop/BADA/프로젝트/11월첫째주과제/영화크롤링_2020_이세은_제출용.csv"); df.head()
# Out:
#        Date Rank                             Title        gross theaters  \
# 0  2020/1/3    1  Star Wars: The Rise of Skywalker  $46,053,249    4,406
# 1  2020/1/3    2           Jumanji: The Next Level  $33,418,576    4,134
# 2  2020/1/3    3                      Little Women  $19,932,677    3,308
# 3  2020/1/3    4                         Frozen II  $15,037,678    3,175
# 4  2020/1/3    5                        The Grudge  $14,406,715    2,642
#
#   per_theater   total_gross  \
# 0     $10,452  $463,110,690
# 1      $8,084  $243,124,981
# 2      $6,026   $66,381,009
# 3      $4,736  $453,623,042
# 4      $5,453   $14,406,715
#
#                                               Genres Original Language  \
# 0                 Sci-fi, Adventure, Action, Fantasy           English
# 1                 Adventure, Action, Comedy, Fantasy           English
# 2                                     Drama, Musical           English
# ...

# %%
#drop columns
df.drop(['theaters', 'per_theater'], axis=1, inplace=True)

# %%
df.rename(columns={'Title': 'Movie Title',
                   'gross': 'Weekly Gross',
                   'total_gross': 'Cumulative Gross',
                   'Genres': 'Genre',
                   'Release Date (Theator)': 'Release Date',
                   'Box Office (Gross USA)': 'Total Gross'
                   }, inplace=True)

# %%
df.head(1)
# Out:
#        Date Rank                       Movie Title Weekly Gross  \
# 0  2020/1/3    1  Star Wars: The Rise of Skywalker  $46,053,249
#
#   Cumulative Gross                               Genre Original Language  \
# 0     $463,110,690  Sci-fi, Adventure, Action, Fantasy           English
#
#       Director  Release Date Runtime  Distributor                   Prod Co.  \
# 0  J.J. Abrams  Dec 20, 2019  2h 22m  Walt Disney  Lucasfilm Ltd., Bad Robot
#
#   Total Gross
# 0     $515.2M

# %%
df.columns
# Out:
# Index(['Date', 'Rank', 'Movie Title', 'Weekly Gross', 'Cumulative Gross',
#        'Genre', 'Original Language', 'Director', 'Release Date', 'Runtime',
#        'Distributor', 'Prod Co.', 'Total Gross'],
#       dtype='object')

# %%
df = df[['Date', 'Rank', 'Movie Title', 'Weekly Gross', 'Cumulative Gross',
       'Genre', 'Original Language', 'Director', 'Release Date', 'Total Gross', 'Runtime',
       'Distributor', 'Prod Co.']]

# %%
df
# Out:
#            Date Rank                       Movie Title Weekly Gross  \
# 0      2020/1/3    1  Star Wars: The Rise of Skywalker  $46,053,249
# 1      2020/1/3    2           Jumanji: The Next Level  $33,418,576
# 2      2020/1/3    3                      Little Women  $19,932,677
# 3      2020/1/3    4                         Frozen II  $15,037,678
# 4      2020/1/3    5                        The Grudge  $14,406,715
# ..          ...  ...                               ...          ...
# 804  2020/12/25    -                       All My Life      $23,840
# 805  2020/12/25    -                  Always & Forever      $18,674
# 806  2020/12/25    -                        Let Him Go      $12,315
# 807  2020/12/25    -                         Archenemy      $11,003
# 808  2020/12/25    -              The Forgotten Carols       $9,243
#
#     Cumulative Gross                                              Genre  \
# 0       $463,110,690                 Sci-fi, Adventure, Action, Fantasy
# ...

# %%
df.to_csv('C:/Users/이세은/Desktop/BADA/프로젝트/11월첫째주과제/영화크롤링_2020_칼럼수정까지완료.csv', index=False)
