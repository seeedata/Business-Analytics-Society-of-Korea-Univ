# %% [markdown]
# <a href="https://colab.research.google.com/github/seeedata/BADA/blob/main/DAB/0708%20%EC%A7%80%ED%95%98%EC%B2%A0%20%EC%B5%9C%EC%A2%85%20Data%20Preprocessing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import numpy as np

# %%
sub9 = pd.read_csv('/content/drive/MyDrive/colab_data/9호선최종데이터.csv', encoding='cp949')
sub9
# Out:
#               날짜   호선   역번호     역명   구분  00~01  01~02  02~03  03~04  04~05  \
# 0     2018-12-01  9호선  4135   한성백제  순승차      0      0      0      0      5
# 1     2018-12-01  9호선  4135   한성백제  순하차      0      0      0      0      3
# 2     2018-12-02  9호선  4135   한성백제  순승차      0      0      0      0      0
# 3     2018-12-02  9호선  4135   한성백제  순하차      0      0      0      0      0
# 4     2018-12-03  9호선  4135   한성백제  순승차      3      0      0      0      0
# ...          ...  ...   ...    ...  ...    ...    ...    ...    ...    ...
# 8391  2023-05-29    9  4136  올림픽공원  순하차     26      0      0      0      0
# 8392  2023-05-30    9  4136  올림픽공원  순승차      6      0      0      0      0
# 8393  2023-05-30    9  4136  올림픽공원  순하차     97      0      0      0      0
# 8394  2023-05-31    9  4136  올림픽공원  순승차      3      0      0      0      0
# 8395  2023-05-31    9  4136  올림픽공원  순하차     79      0      0      0      0
#
# ...

# %%
sub9.drop(['역번호'], axis = 1, inplace = True)
sub9
# Out:
#               날짜   호선     역명   구분  00~01  01~02  02~03  03~04  04~05  05~06  \
# 0     2018-12-01  9호선   한성백제  순승차      0      0      0      0      5     22
# 1     2018-12-01  9호선   한성백제  순하차      0      0      0      0      3     12
# 2     2018-12-02  9호선   한성백제  순승차      0      0      0      0      0      4
# 3     2018-12-02  9호선   한성백제  순하차      0      0      0      0      0      2
# 4     2018-12-03  9호선   한성백제  순승차      3      0      0      0      0     18
# ...          ...  ...    ...  ...    ...    ...    ...    ...    ...    ...
# 8391  2023-05-29    9  올림픽공원  순하차     26      0      0      0      0     15
# 8392  2023-05-30    9  올림픽공원  순승차      6      0      0      0      0     95
# 8393  2023-05-30    9  올림픽공원  순하차     97      0      0      0      0     30
# 8394  2023-05-31    9  올림픽공원  순승차      3      0      0      0      0     98
# 8395  2023-05-31    9  올림픽공원  순하차     79      0      0      0      0     32
#
# ...

# %%
sub9['호선'].replace({'9호선': '9'}, inplace = True)
sub9
# Out:
#               날짜 호선     역명   구분  00~01  01~02  02~03  03~04  04~05  05~06  \
# 0     2018-12-01  9   한성백제  순승차      0      0      0      0      5     22
# 1     2018-12-01  9   한성백제  순하차      0      0      0      0      3     12
# 2     2018-12-02  9   한성백제  순승차      0      0      0      0      0      4
# 3     2018-12-02  9   한성백제  순하차      0      0      0      0      0      2
# 4     2018-12-03  9   한성백제  순승차      3      0      0      0      0     18
# ...          ... ..    ...  ...    ...    ...    ...    ...    ...    ...
# 8391  2023-05-29  9  올림픽공원  순하차     26      0      0      0      0     15
# 8392  2023-05-30  9  올림픽공원  순승차      6      0      0      0      0     95
# 8393  2023-05-30  9  올림픽공원  순하차     97      0      0      0      0     30
# 8394  2023-05-31  9  올림픽공원  순승차      3      0      0      0      0     98
# 8395  2023-05-31  9  올림픽공원  순하차     79      0      0      0      0     32
#
#       ...  14~15  15~16  16~17  17~18  18~19  19~20  20~21  21~22  22~23  \
# ...

# %%
sub9
# Out:
#               날짜 호선     역명   구분  00~01  01~02  02~03  03~04  04~05  05~06  \
# 0     2018-12-01  9   한성백제  순승차      0      0      0      0      5     22
# 1     2018-12-01  9   한성백제  순하차      0      0      0      0      3     12
# 2     2018-12-02  9   한성백제  순승차      0      0      0      0      0      4
# 3     2018-12-02  9   한성백제  순하차      0      0      0      0      0      2
# 4     2018-12-03  9   한성백제  순승차      3      0      0      0      0     18
# ...          ... ..    ...  ...    ...    ...    ...    ...    ...    ...
# 8391  2023-05-29  9  올림픽공원  순하차     26      0      0      0      0     15
# 8392  2023-05-30  9  올림픽공원  순승차      6      0      0      0      0     95
# 8393  2023-05-30  9  올림픽공원  순하차     97      0      0      0      0     30
# 8394  2023-05-31  9  올림픽공원  순승차      3      0      0      0      0     98
# 8395  2023-05-31  9  올림픽공원  순하차     79      0      0      0      0     32
#
#       ...  14~15  15~16  16~17  17~18  18~19  19~20  20~21  21~22  22~23  \
# ...

# %%
sub = pd.read_csv('/content/drive/MyDrive/colab_data/5,8호선최종데이터.csv', encoding='cp949')
sub
# Out:
#               날짜  호선   역번호     역명  구분  00~01  01~02  02~03  03~04  04~05  ...  \
# 0     2018-12-01   5  2556  올림픽공원  승차      1      0      0      0      0  ...
# 1     2018-12-01   5  2556  올림픽공원  하차      0      0      0      0      0  ...
# 2     2018-12-01   8  2814   몽촌토성  승차      0      0      0      0      0  ...
# 3     2018-12-01   8  2814   몽촌토성  하차      9      0      0      0      0  ...
# 4     2018-12-02   5  2556  올림픽공원  승차      0      0      0      0      0  ...
# ...          ...  ..   ...    ...  ..    ...    ...    ...    ...    ...  ...
# 6443  2023-04-29   8  2814   몽촌토성  하차      1      0      0      0      0  ...
# 6444  2023-04-30   5  2556  올림픽공원  승차      0      0      0      0      0  ...
# 6445  2023-04-30   5  2556  올림픽공원  하차      1      0      0      0      0  ...
# 6446  2023-04-30   8  2814   몽촌토성  승차      0      0      0      0      0  ...
# 6447  2023-04-30   8  2814   몽촌토성  하차      5      0      0      0      0  ...
#
# ...

# %%
sub.drop('역번호', axis = 1, inplace = True)
sub
# Out:
#               날짜  호선     역명  구분  00~01  01~02  02~03  03~04  04~05  05~06  \
# 0     2018-12-01   5  올림픽공원  승차      1      0      0      0      0     25
# 1     2018-12-01   5  올림픽공원  하차      0      0      0      0      0     31
# 2     2018-12-01   8   몽촌토성  승차      0      0      0      0      0     59
# 3     2018-12-01   8   몽촌토성  하차      9      0      0      0      0     29
# 4     2018-12-02   5  올림픽공원  승차      0      0      0      0      0      9
# ...          ...  ..    ...  ..    ...    ...    ...    ...    ...    ...
# 6443  2023-04-29   8   몽촌토성  하차      1      0      0      0      0     40
# 6444  2023-04-30   5  올림픽공원  승차      0      0      0      0      0     30
# 6445  2023-04-30   5  올림픽공원  하차      1      0      0      0      0     16
# 6446  2023-04-30   8   몽촌토성  승차      0      0      0      0      0     43
# 6447  2023-04-30   8   몽촌토성  하차      5      0      0      0      0     19
#
#       ...  14~15  15~16  16~17  17~18  18~19  19~20  20~21  21~22  22~23  \
# ...

# %%
data_sub = pd.concat([sub9, sub], axis = 0)
data_sub
# Out:
#               날짜 호선     역명   구분  00~01  01~02  02~03  03~04  04~05  05~06  \
# 0     2018-12-01  9   한성백제  순승차      0      0      0      0      5     22
# 1     2018-12-01  9   한성백제  순하차      0      0      0      0      3     12
# 2     2018-12-02  9   한성백제  순승차      0      0      0      0      0      4
# 3     2018-12-02  9   한성백제  순하차      0      0      0      0      0      2
# 4     2018-12-03  9   한성백제  순승차      3      0      0      0      0     18
# ...          ... ..    ...  ...    ...    ...    ...    ...    ...    ...
# 6443  2023-04-29  8   몽촌토성   하차      1      0      0      0      0     40
# 6444  2023-04-30  5  올림픽공원   승차      0      0      0      0      0     30
# 6445  2023-04-30  5  올림픽공원   하차      1      0      0      0      0     16
# 6446  2023-04-30  8   몽촌토성   승차      0      0      0      0      0     43
# 6447  2023-04-30  8   몽촌토성   하차      5      0      0      0      0     19
#
#       ...  14~15  15~16  16~17  17~18  18~19  19~20  20~21  21~22  22~23  \
# ...

# %%
data_sub.sort_values(['날짜', '역명', '구분'], inplace = True)
data_sub
# Out:
#               날짜 호선     역명   구분  00~01  01~02  02~03  03~04  04~05  05~06  \
# 2     2018-12-01  8   몽촌토성   승차      0      0      0      0      0     59
# 3     2018-12-01  8   몽촌토성   하차      9      0      0      0      0     29
# 62    2018-12-01  9  올림픽공원  순승차      0      0      0      0      4     20
# 64    2018-12-01  9  올림픽공원  순하차      4      0      0      0      4      3
# 0     2018-12-01  5  올림픽공원   승차      1      0      0      0      0     25
# ...          ... ..    ...  ...    ...    ...    ...    ...    ...    ...
# 8331  2023-05-30  9   한성백제  순하차     45      0      0      0      0     11
# 8394  2023-05-31  9  올림픽공원  순승차      3      0      0      0      0     98
# 8395  2023-05-31  9  올림픽공원  순하차     79      0      0      0      0     32
# 8332  2023-05-31  9   한성백제  순승차      6      0      0      0      0     46
# 8333  2023-05-31  9   한성백제  순하차     33      0      0      0      0      9
#
#       ...  14~15  15~16  16~17  17~18  18~19  19~20  20~21  21~22  22~23  \
# ...

# %%
data_sub.to_csv('/content/drive/MyDrive/colab_data/지하철최종데이터.csv', index = False, encoding = 'cp949')
