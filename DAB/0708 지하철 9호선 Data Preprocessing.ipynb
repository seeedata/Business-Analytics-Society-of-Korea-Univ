# %% [markdown]
# <a href="https://colab.research.google.com/github/seeedata/BADA/blob/main/DAB/0708%20%EC%A7%80%ED%95%98%EC%B2%A0%209%ED%98%B8%EC%84%A0%20Data%20Preprocessing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import numpy as np

# %%
sub9_18 = pd.read_csv('/content/drive/MyDrive/colab_data/서울교통공사_9호선2-3단계역별일별시간대별승하차인원_20181231.csv', encoding='cp949')
sub9_18.head()
# Out:
#            날짜   호선   역번호  역명   구분  00~01  01~02  02~03  03~04  04~05  ...  \
# 0  2018-01-01  9호선  4126  언주  순승차      0      0      0      0      3  ...
# 1  2018-01-01  9호선  4126  언주  순하차      2      0      0      0      0  ...
# 2  2018-01-02  9호선  4126  언주  순승차     21      0      0      0      0  ...
# 3  2018-01-02  9호선  4126  언주  순하차     43      0      0      0      0  ...
# 4  2018-01-03  9호선  4126  언주  순승차     29      0      0      0      0  ...
#
#    14~15  15~16  16~17  17~18  18~19  19~20  20~21  21~22  22~23  23~24
# 0    164    170    172    177    189    137    102    123     87     45
# 1    153    157    164    194    227    136    172    204    121    101
# 2    359    420    504    817   1929   1202    536    483    334    152
# 3    349    332    375    371    421    445    243    259    197    110
# 4    357    469    543    931   1988   1169    586    509    354    170
#
# [5 rows x 29 columns]

# %%
sub9_18 = sub9_18[(sub9_18['역명'] == '한성백제') | (sub9_18['역명'] == '올림픽공원')]
sub9_18
# Out:
#               날짜   호선   역번호     역명    구분  00~01  01~02  02~03  03~04  04~05  \
# 5420  2018-12-01  9호선  4135   한성백제   순승차      0      0      0      0      5
# 5421  2018-12-01  9호선  4135   한성백제   순하차      0      0      0      0      3
# 5422  2018-12-02  9호선  4135   한성백제   순승차      0      0      0      0      0
# 5423  2018-12-02  9호선  4135   한성백제   순하차      0      0      0      0      0
# 5424  2018-12-03  9호선  4135   한성백제   순승차      3      0      0      0      0
# ...          ...  ...   ...    ...   ...    ...    ...    ...    ...    ...
# 5601  2018-12-30  9호선  4136  올림픽공원  환승하차      0      0      0      0      0
# 5602  2018-12-31  9호선  4136  올림픽공원   순승차     30    267      1      0      0
# 5603  2018-12-31  9호선  4136  올림픽공원  환승승차     38     38      1      0      0
# 5604  2018-12-31  9호선  4136  올림픽공원   순하차    100     35      9      0      0
# 5605  2018-12-31  9호선  4136  올림픽공원  환승하차    100    102      0      0      0
#
# ...

# %%
sub9_19 = pd.read_csv('/content/drive/MyDrive/colab_data/서울교통공사_9호선2-3단계역별일별시간대별승하차인원_20191231.csv', encoding='cp949')
sub9_19.head()
# Out:
#            날짜   호선   역번호  역명   구분  00~01  01~02  02~03  03~04  04~05  ...  \
# 0  2019-01-01  9호선  4126  언주  순승차      0      0      0      0      0  ...
# 1  2019-01-01  9호선  4126  언주  순하차      5      0      0      0      0  ...
# 2  2019-01-02  9호선  4126  언주  순승차     39      1      0      0      0  ...
# 3  2019-01-02  9호선  4126  언주  순하차     53      1      0      0      0  ...
# 4  2019-01-03  9호선  4126  언주  순승차     44      0      0      0      0  ...
#
#    14~15  15~16  16~17  17~18  18~19  19~20  20~21  21~22  22~23  23~24
# 0    185    201    172    176    220    138    123    120    117     38
# 1    159    161    199    192    211    177    205    172    188    100
# 2    443    485    552   1227   2280   1197    642    547    368    141
# 3    388    368    435    394    571    489    267    231    225    154
# 4    513    541    643   1150   2320   1191    591    538    383    187
#
# [5 rows x 29 columns]

# %%
sub9_19 = sub9_19[(sub9_19['역명'] == '한성백제') | (sub9_19['역명'] == '올림픽공원')]
sub9_19
# Out:
#                날짜   호선   역번호     역명    구분  00~01  01~02  02~03  03~04  04~05  \
# 8760   2019-01-01  9호선  4135   한성백제   순승차      0      0      0      0      0
# 8761   2019-01-01  9호선  4135   한성백제   순하차      0      0      0      0      0
# 8762   2019-01-02  9호선  4135   한성백제   순승차      4      0      0      0      0
# 8763   2019-01-02  9호선  4135   한성백제   순하차     29      0      0      0      0
# 8764   2019-01-03  9호선  4135   한성백제   순승차      5      0      0      0      1
# ...           ...  ...   ...    ...   ...    ...    ...    ...    ...    ...
# 10945  2019-12-30  9호선  4136  올림픽공원  환승하차     55      0      0      0      0
# 10946  2019-12-31  9호선  4136  올림픽공원   순승차    435    139      0      0     21
# 10947  2019-12-31  9호선  4136  올림픽공원  환승승차     44     51      0      0      0
# 10948  2019-12-31  9호선  4136  올림픽공원   순하차     90     47      4      0      0
# 10949  2019-12-31  9호선  4136  올림픽공원  환승하차    260    120      0      0      0
#
# ...

# %%
sub9_20 = pd.read_csv('/content/drive/MyDrive/colab_data/서울교통공사_9호선2-3단계역별일별시간대별승하차인원_20201231.csv', encoding='cp949')
sub9_20.head()
# Out:
#            날짜   호선   역번호  역명   구분  00~01  01~02  02~03  03~04  04~05  ...  \
# 0  2020-01-01  9호선  4126  언주  순승차      0      0      0      0      0  ...
# 1  2020-01-01  9호선  4126  언주  순하차      5      0      0      0      0  ...
# 2  2020-01-02  9호선  4126  언주  순승차     27      0      0      0      0  ...
# 3  2020-01-02  9호선  4126  언주  순하차     72      4      0      0      0  ...
# 4  2020-01-03  9호선  4126  언주  순승차     45      0      0      0      0  ...
#
#    14~15  15~16  16~17  17~18  18~19  19~20  20~21  21~22  22~23  23~24
# 0    203    214    198    200    201    156    123    139    101     58
# 1    152    196    155    241    185    184    195    181    175    110
# 2    443    530    702   1263   2315   1194    552    522    378    145
# 3    399    426    370    436    603    460    289    265    202    177
# 4    534    590    742   1307   2560   1169    599    586    425    203
#
# [5 rows x 29 columns]

# %%
sub9_20 = sub9_20[(sub9_20['역명'] == '한성백제') | (sub9_20['역명'] == '올림픽공원')]
sub9_20
# Out:
#                날짜   호선   역번호     역명    구분  00~01  01~02  02~03  03~04  04~05  \
# 8784   2020-01-01  9호선  4135   한성백제   순승차      0      0      0      0      0
# 8785   2020-01-01  9호선  4135   한성백제   순하차      0      0      0      0      0
# 8786   2020-01-02  9호선  4135   한성백제   순승차      4      0      0      0      0
# 8787   2020-01-02  9호선  4135   한성백제   순하차     34      0      0      0      0
# 8788   2020-01-03  9호선  4135   한성백제   순승차     10      0      0      0      0
# ...           ...  ...   ...    ...   ...    ...    ...    ...    ...    ...
# 10975  2020-12-30  9호선  4136  올림픽공원  환승하차      0      0      0      0      0
# 10976  2020-12-31  9호선  4136  올림픽공원   순승차      0      0      0      0      0
# 10977  2020-12-31  9호선  4136  올림픽공원  환승승차      0      0      0      0      0
# 10978  2020-12-31  9호선  4136  올림픽공원   순하차      0      0      0      0      0
# 10979  2020-12-31  9호선  4136  올림픽공원  환승하차      0      0      0      0      0
#
# ...

# %%
sub9_21 = pd.read_csv('/content/drive/MyDrive/colab_data/서울교통공사_9호선 2_3단계 역별일별시간대별승하차인원_20211231.csv', encoding='cp949')
sub9_21.head()
# Out:
#    연번          날짜  호선   역번호 역사명   구분  00시-01시  01시-02시  02시-03시  03시-04시  ...  \
# 0   1  2021-01-01   9  4126  언주  순승차        0        0        0        0  ...
# 1   2  2021-01-01   9  4126  언주  순하차        3        0        0        0  ...
# 2   3  2021-01-02   9  4126  언주  순승차        0        0        0        0  ...
# 3   4  2021-01-02   9  4126  언주  순하차        2        0        0        0  ...
# 4   5  2021-01-03   9  4126  언주  순승차        0        0        0        0  ...
#
#    14시-15시  15시-16시  16시-17시  17시-18시  18시-19시  19시-20시  20시-21시  21시-22시  \
# 0       90      129      125      124      100       67       90       71
# 1       86       98       91      111       84       74       70       90
# 2      213      237      255      214      162      129      117      117
# 3      190      171      138      173      121      100      108      111
# 4      128      141      137      152      118      103      105      104
#
#    22시-23시  23시-24시
# 0       64       11
# ...

# %%
sub9_21 = sub9_21[(sub9_21['역사명'] == '한성백제') | (sub9_21['역사명'] == '올림픽공원')]
sub9_21
# Out:
#           연번          날짜  호선   역번호    역사명   구분  00시-01시  01시-02시  02시-03시  \
# 744      745  2021-01-01   9  4135   한성백제  순승차        0        0        0
# 745      746  2021-01-01   9  4135   한성백제  순하차        2        0        0
# 746      747  2021-01-02   9  4135   한성백제  순승차        0        0        0
# 747      748  2021-01-02   9  4135   한성백제  순하차        0        0        0
# 748      749  2021-01-03   9  4135   한성백제  순승차        0        0        0
# ...      ...         ...  ..   ...    ...  ...      ...      ...      ...
# 10561  10562  2021-12-29   9  4136  올림픽공원  순하차        0        0        0
# 10562  10563  2021-12-30   9  4136  올림픽공원  순승차        0        0        0
# 10563  10564  2021-12-30   9  4136  올림픽공원  순하차        0        0        0
# 10564  10565  2021-12-31   9  4136  올림픽공원  순승차        0        0        0
# 10565  10566  2021-12-31   9  4136  올림픽공원  순하차        0        0        0
#
#        03시-04시  ...  14시-15시  15시-16시  16시-17시  17시-18시  18시-19시  19시-20시  \
# ...

# %%
sub9_21 = sub9_21.drop('연번', axis = 1)
sub9_21
# Out:
#                날짜  호선   역번호    역사명   구분  00시-01시  01시-02시  02시-03시  03시-04시  \
# 744    2021-01-01   9  4135   한성백제  순승차        0        0        0        0
# 745    2021-01-01   9  4135   한성백제  순하차        2        0        0        0
# 746    2021-01-02   9  4135   한성백제  순승차        0        0        0        0
# 747    2021-01-02   9  4135   한성백제  순하차        0        0        0        0
# 748    2021-01-03   9  4135   한성백제  순승차        0        0        0        0
# ...           ...  ..   ...    ...  ...      ...      ...      ...      ...
# 10561  2021-12-29   9  4136  올림픽공원  순하차        0        0        0        0
# 10562  2021-12-30   9  4136  올림픽공원  순승차        0        0        0        0
# 10563  2021-12-30   9  4136  올림픽공원  순하차        0        0        0        0
# 10564  2021-12-31   9  4136  올림픽공원  순승차        0        0        0        0
# 10565  2021-12-31   9  4136  올림픽공원  순하차        0        0        0        0
#
# ...

# %%
sub9_21.columns = ['날짜', '호선', '역번호', '역명', '구분', '00~01', '01~02', '02~03', '03~04',
       '04~05', '05~06', '06~07', '07~08', '08~09', '09~10', '10~11', '11~12',
       '12~13', '13~14', '14~15', '15~16', '16~17', '17~18', '18~19', '19~20',
       '20~21', '21~22', '22~23', '23~24']
sub9_21
# Out:
#                날짜  호선   역번호     역명   구분  00~01  01~02  02~03  03~04  04~05  \
# 744    2021-01-01   9  4135   한성백제  순승차      0      0      0      0      0
# 745    2021-01-01   9  4135   한성백제  순하차      2      0      0      0      0
# 746    2021-01-02   9  4135   한성백제  순승차      0      0      0      0      0
# 747    2021-01-02   9  4135   한성백제  순하차      0      0      0      0      0
# 748    2021-01-03   9  4135   한성백제  순승차      0      0      0      0      0
# ...           ...  ..   ...    ...  ...    ...    ...    ...    ...    ...
# 10561  2021-12-29   9  4136  올림픽공원  순하차      0      0      0      0      0
# 10562  2021-12-30   9  4136  올림픽공원  순승차      0      0      0      0      0
# 10563  2021-12-30   9  4136  올림픽공원  순하차      0      0      0      0      0
# 10564  2021-12-31   9  4136  올림픽공원  순승차      0      0      0      0      0
# 10565  2021-12-31   9  4136  올림픽공원  순하차      0      0      0      0      0
#
# ...

# %%
sub9_22 = pd.read_csv('/content/drive/MyDrive/colab_data/서울교통공사_9호선2_3단계 역별일별시간대별승하차인원_20221231.csv', encoding='cp949')
sub9_22.head()
# Out:
#    연번        수송일자  호선  고유역번호(외부역코드)  역명 승하차구분  00-01시간대  01-02시간대  02-03시간대  \
# 0   1  2022-01-01   9          4126  언주   순승차         0         0         0
# 1   2  2022-01-01   9          4126  언주   순하차         2         0         0
# 2   3  2022-01-02   9          4126  언주   순승차         0         0         0
# 3   4  2022-01-02   9          4126  언주   순하차         3         0         0
# 4   5  2022-01-03   9          4126  언주   순승차         0         0         0
#
#    03-04시간대  ...  14-15시간대  15-16시간대  16-17시간대  17-18시간대  18-19시간대  19-20시간대  \
# 0         0  ...       218       164       162       168       106        99
# 1         0  ...       140       159       135       188       146       105
# 2         0  ...       218       244       275       250       197       168
# 3         0  ...       210       228       191       218       178       140
# 4         0  ...       422       474       633      1544      2549      1168
#
#    20-21시간대  21-22시간대  22-23시간대  23-24시간대
# ...

# %%
sub9_22 = sub9_22[(sub9_22['역명'] == '한성백제') | (sub9_22['역명'] == '올림픽공원')]
sub9_22
# Out:
#         연번        수송일자  호선  고유역번호(외부역코드)     역명 승하차구분  00-01시간대  01-02시간대  \
# 6570  6571  2022-01-01   9          4135   한성백제   순승차         0         0
# 6571  6572  2022-01-01   9          4135   한성백제   순하차         2         0
# 6572  6573  2022-01-02   9          4135   한성백제   순승차         0         0
# 6573  6574  2022-01-02   9          4135   한성백제   순하차         4         0
# 6574  6575  2022-01-03   9          4135   한성백제   순승차         0         0
# ...    ...         ...  ..           ...    ...   ...       ...       ...
# 8025  8026  2022-12-29   9          4136  올림픽공원   순하차       103         0
# 8026  8027  2022-12-30   9          4136  올림픽공원   순승차        33         0
# 8027  8028  2022-12-30   9          4136  올림픽공원   순하차       118         0
# 8028  8029  2022-12-31   9          4136  올림픽공원   순승차         8         3
# 8029  8030  2022-12-31   9          4136  올림픽공원   순하차        31        17
#
#       02-03시간대  03-04시간대  ...  14-15시간대  15-16시간대  16-17시간대  17-18시간대  \
# ...

# %%
sub9_22 = sub9_22.drop('연번', axis = 1)
sub9_22
# Out:
#             수송일자  호선  고유역번호(외부역코드)     역명 승하차구분  00-01시간대  01-02시간대  02-03시간대  \
# 6570  2022-01-01   9          4135   한성백제   순승차         0         0         0
# 6571  2022-01-01   9          4135   한성백제   순하차         2         0         0
# 6572  2022-01-02   9          4135   한성백제   순승차         0         0         0
# 6573  2022-01-02   9          4135   한성백제   순하차         4         0         0
# 6574  2022-01-03   9          4135   한성백제   순승차         0         0         0
# ...          ...  ..           ...    ...   ...       ...       ...       ...
# 8025  2022-12-29   9          4136  올림픽공원   순하차       103         0         0
# 8026  2022-12-30   9          4136  올림픽공원   순승차        33         0         0
# 8027  2022-12-30   9          4136  올림픽공원   순하차       118         0         0
# 8028  2022-12-31   9          4136  올림픽공원   순승차         8         3         0
# 8029  2022-12-31   9          4136  올림픽공원   순하차        31        17         7
#
# ...

# %%
sub9_22.columns = ['날짜', '호선', '역번호', '역명', '구분', '00~01', '01~02', '02~03', '03~04',
       '04~05', '05~06', '06~07', '07~08', '08~09', '09~10', '10~11', '11~12',
       '12~13', '13~14', '14~15', '15~16', '16~17', '17~18', '18~19', '19~20',
       '20~21', '21~22', '22~23', '23~24']
sub9_22
# Out:
#               날짜  호선   역번호     역명   구분  00~01  01~02  02~03  03~04  04~05  \
# 6570  2022-01-01   9  4135   한성백제  순승차      0      0      0      0      0
# 6571  2022-01-01   9  4135   한성백제  순하차      2      0      0      0      0
# 6572  2022-01-02   9  4135   한성백제  순승차      0      0      0      0      0
# 6573  2022-01-02   9  4135   한성백제  순하차      4      0      0      0      0
# 6574  2022-01-03   9  4135   한성백제  순승차      0      0      0      0      0
# ...          ...  ..   ...    ...  ...    ...    ...    ...    ...    ...
# 8025  2022-12-29   9  4136  올림픽공원  순하차    103      0      0      0      0
# 8026  2022-12-30   9  4136  올림픽공원  순승차     33      0      0      0      0
# 8027  2022-12-30   9  4136  올림픽공원  순하차    118      0      0      0      0
# 8028  2022-12-31   9  4136  올림픽공원  순승차      8      3      0      0      0
# 8029  2022-12-31   9  4136  올림픽공원  순하차     31     17      7      0      0
#
#       ...  14~15  15~16  16~17  17~18  18~19  19~20  20~21  21~22  22~23  \
# ...

# %%
sub9_23 = pd.read_csv('/content/drive/MyDrive/colab_data/서울교통공사_9호선 2_3단계 역별일별시간대별승하차인원_20230531.csv', encoding = 'cp949')
sub9_23.head()
# Out:
#    연번        수송일자  호선   역번호  역명 승하차구분  00-01시간대  01-02시간대  02-03시간대  03-04시간대  \
# 0   1  2023-01-01   9  4126  언주   순승차         0         0         0         0
# 1   2  2023-01-01   9  4126  언주   순하차         7         0         0         0
# 2   3  2023-01-02   9  4126  언주   순승차        23         0         0         0
# 3   4  2023-01-02   9  4126  언주   순하차        41         3         0         0
# 4   5  2023-01-03   9  4126  언주   순승차        17         0         0         0
#
#    ...  14-15시간대  15-16시간대  16-17시간대  17-18시간대  18-19시간대  19-20시간대  20-21시간대  \
# 0  ...       170       215       220       166       136       118        93
# 1  ...       154       170       154       180       148       146       176
# 2  ...       376       512       766      1706      2732      1216       547
# 3  ...       296       344       278       389       502       416       235
# 4  ...       420       567       777      1758      2747      1279       664
#
#    21-22시간대  22-23시간대  23-24시간대
# ...

# %%
sub9_23 = sub9_23[(sub9_23['역명'] == '한성백제') | (sub9_23['역명'] == '올림픽공원')]
sub9_23
# Out:
#         연번        수송일자  호선   역번호     역명 승하차구분  00-01시간대  01-02시간대  02-03시간대  \
# 2160  2161  2023-01-01   9  4135   한성백제   순승차         0         0         0
# 2161  2162  2023-01-01   9  4135   한성백제   순하차         2         0         0
# 2162  2163  2023-01-02   9  4135   한성백제   순승차         5         0         0
# 2163  2164  2023-01-02   9  4135   한성백제   순하차        11         0         0
# 2164  2165  2023-01-03   9  4135   한성백제   순승차         3         0         0
# ...    ...         ...  ..   ...    ...   ...       ...       ...       ...
# 3797  3798  2023-05-29   9  4136  올림픽공원   순하차        26         0         0
# 3798  3799  2023-05-30   9  4136  올림픽공원   순승차         6         0         0
# 3799  3800  2023-05-30   9  4136  올림픽공원   순하차        97         0         0
# 3800  3801  2023-05-31   9  4136  올림픽공원   순승차         3         0         0
# 3801  3802  2023-05-31   9  4136  올림픽공원   순하차        79         0         0
#
# ...

# %%
sub9_23 = sub9_23.drop('연번', axis = 1)
sub9_23
# Out:
#             수송일자  호선   역번호     역명 승하차구분  00-01시간대  01-02시간대  02-03시간대  \
# 2160  2023-01-01   9  4135   한성백제   순승차         0         0         0
# 2161  2023-01-01   9  4135   한성백제   순하차         2         0         0
# 2162  2023-01-02   9  4135   한성백제   순승차         5         0         0
# 2163  2023-01-02   9  4135   한성백제   순하차        11         0         0
# 2164  2023-01-03   9  4135   한성백제   순승차         3         0         0
# ...          ...  ..   ...    ...   ...       ...       ...       ...
# 3797  2023-05-29   9  4136  올림픽공원   순하차        26         0         0
# 3798  2023-05-30   9  4136  올림픽공원   순승차         6         0         0
# 3799  2023-05-30   9  4136  올림픽공원   순하차        97         0         0
# 3800  2023-05-31   9  4136  올림픽공원   순승차         3         0         0
# 3801  2023-05-31   9  4136  올림픽공원   순하차        79         0         0
#
#       03-04시간대  04-05시간대  ...  14-15시간대  15-16시간대  16-17시간대  17-18시간대  \
# ...

# %%
sub9_23.columns = ['날짜', '호선', '역번호', '역명', '구분', '00~01', '01~02', '02~03', '03~04',
       '04~05', '05~06', '06~07', '07~08', '08~09', '09~10', '10~11', '11~12',
       '12~13', '13~14', '14~15', '15~16', '16~17', '17~18', '18~19', '19~20',
       '20~21', '21~22', '22~23', '23~24']
sub9_23
# Out:
#               날짜  호선   역번호     역명   구분  00~01  01~02  02~03  03~04  04~05  \
# 2160  2023-01-01   9  4135   한성백제  순승차      0      0      0      0      0
# 2161  2023-01-01   9  4135   한성백제  순하차      2      0      0      0      0
# 2162  2023-01-02   9  4135   한성백제  순승차      5      0      0      0      0
# 2163  2023-01-02   9  4135   한성백제  순하차     11      0      0      0      0
# 2164  2023-01-03   9  4135   한성백제  순승차      3      0      0      0      0
# ...          ...  ..   ...    ...  ...    ...    ...    ...    ...    ...
# 3797  2023-05-29   9  4136  올림픽공원  순하차     26      0      0      0      0
# 3798  2023-05-30   9  4136  올림픽공원  순승차      6      0      0      0      0
# 3799  2023-05-30   9  4136  올림픽공원  순하차     97      0      0      0      0
# 3800  2023-05-31   9  4136  올림픽공원  순승차      3      0      0      0      0
# 3801  2023-05-31   9  4136  올림픽공원  순하차     79      0      0      0      0
#
#       ...  14~15  15~16  16~17  17~18  18~19  19~20  20~21  21~22  22~23  \
# ...

# %%
sub9 = pd.concat([sub9_18, sub9_19, sub9_20, sub9_21, sub9_22, sub9_23], axis = 0)
sub9
# Out:
#               날짜   호선   역번호     역명   구분  00~01  01~02  02~03  03~04  04~05  \
# 5420  2018-12-01  9호선  4135   한성백제  순승차      0      0      0      0      5
# 5421  2018-12-01  9호선  4135   한성백제  순하차      0      0      0      0      3
# 5422  2018-12-02  9호선  4135   한성백제  순승차      0      0      0      0      0
# 5423  2018-12-02  9호선  4135   한성백제  순하차      0      0      0      0      0
# 5424  2018-12-03  9호선  4135   한성백제  순승차      3      0      0      0      0
# ...          ...  ...   ...    ...  ...    ...    ...    ...    ...    ...
# 3797  2023-05-29    9  4136  올림픽공원  순하차     26      0      0      0      0
# 3798  2023-05-30    9  4136  올림픽공원  순승차      6      0      0      0      0
# 3799  2023-05-30    9  4136  올림픽공원  순하차     97      0      0      0      0
# 3800  2023-05-31    9  4136  올림픽공원  순승차      3      0      0      0      0
# 3801  2023-05-31    9  4136  올림픽공원  순하차     79      0      0      0      0
#
# ...

# %%
sub9.to_csv('/content/drive/MyDrive/colab_data/9호선최종데이터.csv', index = False, encoding = 'cp949')
