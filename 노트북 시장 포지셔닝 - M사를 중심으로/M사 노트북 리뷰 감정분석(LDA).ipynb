# %% [markdown]
# <a href="https://colab.research.google.com/github/seeedata/BADA/blob/main/%EB%85%B8%ED%8A%B8%EB%B6%81%20%EC%8B%9C%EC%9E%A5%20%ED%8F%AC%EC%A7%80%EC%85%94%EB%8B%9D%20-%20M%EC%82%AC%EB%A5%BC%20%EC%A4%91%EC%8B%AC%EC%9C%BC%EB%A1%9C/M%EC%82%AC%20%EB%85%B8%ED%8A%B8%EB%B6%81%20%EB%A6%AC%EB%B7%B0%20%EA%B0%90%EC%A0%95%EB%B6%84%EC%84%9D(LDA).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from konlpy.tag import Okt
from tqdm import tqdm
import csv
from gensim.corpora import Dictionary
from gensim.models.ldamodel import LdaModel
from collections import Counter
# Out:
# c:\users\ghkd1\appdata\local\programs\python\python38\lib\site-packages\gensim\utils.py:1197: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")

# %%
# 텍스트에서 명사와 형용사를 추출하는 함수
def get_nouns(tokenizer, sentence):
    tagged = tokenizer.pos(sentence)
    nouns = [s for s, t in tagged if t in ['Noun', 'Adjective'] and len(s) > 1]
    return nouns

# 데이터 프레임의 텍스트를 토큰화하는 함수
def tokenize(df):
    tokenizer = Okt()  # Okt 객체 생성
    processed_data = []
    for sent in tqdm(df['text']):
        sentence = str(sent).replace("\n", "").strip()
        processed_data.append(get_nouns(tokenizer, sentence))
    return processed_data

# 처리된 데이터를 파일로 저장하는 함수
def save_processed_data(processed_data, title):
    with open("tokenized_data_"+title, 'w', newline="", encoding='utf-8') as f:
        writer = csv.writer(f)
        for data in processed_data:
            writer.writerow(data)

# 메인 함수
if __name__ == '__main__':
    # 데이터 로드
    df = pd.read_csv(r'C:\Users\ghkd1\OneDrive\문서\카카오톡 받은 파일\review_naver최종.csv')
    df.columns = ['rating', 'text']
    df.dropna(how='any', inplace=True)

    # 평점이 4, 5인 리뷰 처리
    high_rating_df = df[df['rating'].isin(['평점4', '평점5'])]
    high_rating_data = tokenize(high_rating_df)
    save_processed_data(high_rating_data, 'naver_review_high_rating')

    # 평점이 1, 2, 3인 리뷰 처리
    low_rating_df = df[df['rating'].isin(['평점1','평점2', '평점4'])]
    low_rating_data = tokenize(low_rating_df)
    save_processed_data(low_rating_data, 'naver_review_low_rating')
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 676/676 [00:08<00:00, 77.15it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████| 45/45 [00:00<00:00, 210.84it/s]

# %%
# 빈 문서를 제거하는 함수
def remove_empty_docs(data):
    return [doc for doc in data if doc]
high_rating_data_clean = remove_empty_docs(high_rating_data)
low_rating_data_clean = remove_empty_docs(low_rating_data)

# 사전과 코퍼스 생성
positive_dictionary = Dictionary(high_rating_data_clean)
positive_corpus = [positive_dictionary.doc2bow(doc) for doc in high_rating_data_clean]

negative_dictionary = Dictionary(low_rating_data_clean)
negative_corpus = [negative_dictionary.doc2bow(doc) for doc in low_rating_data_clean]

# %%
# 긍정적 리뷰에 대한 LDA 모델 훈련
positive_model = LdaModel(corpus=positive_corpus, id2word=positive_dictionary)

# 부정적 리뷰에 대한 LDA 모델 훈련
negative_model = LdaModel(corpus=negative_corpus, id2word=negative_dictionary)

# 긍정적 리뷰의 주제와 상위 단어 출력
print("긍정적 리뷰의 주제:")
for idx, topic in positive_model.print_topics(-1):
    print('Topic: {} \nWords: {}'.format(idx, topic))

# 부정적 리뷰의 주제와 상위 단어 출력
print("\n부정적 리뷰의 주제:")
for idx, topic in negative_model.print_topics(-1):
    print('Topic: {} \nWords: {}'.format(idx, topic))
# Out:
# 긍정적 리뷰의 주제:
# Topic: 0
# Words: 0.033*"서피스" + 0.029*"휴대" + 0.021*"좋습니다" + 0.021*"지름신" + 0.021*"처음" + 0.021*"좀더" + 0.021*"보태" + 0.019*"구매" + 0.015*"좋고" + 0.014*"매우"
# Topic: 1
# Words: 0.000*"여기저기" + 0.000*"결재" + 0.000*"입니다요" + 0.000*"코드" + 0.000*"편했거든요" + 0.000*"사지" + 0.000*"신뢰" + 0.000*"어렵지만" + 0.000*"있는데전혀" + 0.000*"도우"
# Topic: 2
# Words: 0.035*"만족" + 0.027*"배송" + 0.025*"서피스" + 0.022*"노트북" + 0.022*"입니다" + 0.018*"휴대" + 0.018*"대학생" + 0.018*"선물" + 0.018*"성도" + 0.018*"좋고"
# Topic: 3
# Words: 0.022*"서피스" + 0.022*"생각" + 0.017*"고민" + 0.017*"정말" + 0.015*"노트북" + 0.014*"장점" + 0.012*"모델" + 0.012*"성능" + 0.010*"차이" + 0.009*"프로"
# Topic: 4
# Words: 0.061*"구입" + 0.051*"모델" + 0.021*"사용" + 0.021*"입니다" + 0.021*"조금" + 0.021*"태블릿" + 0.021*"같습니다" + 0.021*"성능" + 0.021*"노트북" + 0.010*"필요하고"
# Topic: 5
# Words: 0.017*"제품" + 0.016*"정말" + 0.015*"좋은" + 0.015*"생각" + 0.015*"차이" + 0.014*"가격" + 0.012*"보드" + 0.012*"세로" + 0.011*"서피스" + 0.011*"입니다"
# Topic: 6
# Words: 0.023*"키보" + 0.023*"사용" + 0.023*"기대했던만큼" + 0.023*"노트북" + 0.023*"퀄리티" + 0.023*"아니지만" + 0.023*"이뻐요" + 0.023*"교체" + 0.023*"처럼" + 0.023*"다른"
# Topic: 7
# Words: 0.059*"사용" + 0.030*"노트북" + 0.030*"구매" + 0.023*"태블릿" + 0.020*"서피스" + 0.017*"고민" + 0.015*"제품" + 0.015*"할인" + 0.014*"게임" + 0.012*"윈도우즈"
# Topic: 8
# Words: 0.019*"윈도우" + 0.017*"평가" + 0.017*"제품" + 0.015*"사용" + 0.014*"퍼포먼스" + 0.012*"서피스" + 0.011*"프로" + 0.011*"비교" + 0.010*"향후" + 0.010*"태블릿"
# Topic: 9
# Words: 0.082*"배송" + 0.055*"빠릅니다" + 0.027*"안되는것" + 0.027*"터치" + 0.027*"성능" + 0.027*"크기" + 0.027*"같아요" + 0.027*"인식" + 0.027*"듭니" + 0.027*"좋습니다"
# Topic: 10
# Words: 0.029*"서피스" + 0.025*"사용" + 0.024*"윈도우" + 0.022*"만족합니다" + 0.020*"작업" + 0.015*"환경" + 0.014*"생각" + 0.012*"프로" + 0.012*"가격" + 0.012*"구매"
# Topic: 11
# Words: 0.022*"배송" + 0.019*"구입" + 0.015*"사용" + 0.015*"배터리" + 0.014*"비교" + 0.013*"서피스" + 0.013*"스토리" + 0.013*"용량" + 0.012*"좋네요" + 0.012*"아쉬운"
# Topic: 12
# Words: 0.037*"서피스" + 0.037*"아주" + 0.025*"노트북" + 0.023*"있음" + 0.019*"슬림펜" + 0.019*"듭니" + 0.019*"전부" + 0.019*"좋습니다" + 0.019*"배송" + 0.019*"본체"
# Topic: 13
# Words: 0.032*"윈도우" + 0.024*"아주" + 0.024*"구매" + 0.022*"부착" + 0.021*"디자인" + 0.016*"배송" + 0.016*"빠르고" + 0.016*"성능" + 0.016*"휴대" + 0.016*"좋습니다"
# Topic: 14
# Words: 0.068*"서피스" + 0.021*"프로" + 0.021*"좋네요" + 0.015*"배송" + 0.015*"작업" + 0.015*"구매" + 0.013*"노트북" + 0.010*"제품" + 0.009*"입니다" + 0.009*"디자인"
# Topic: 15
# Words: 0.037*"노트북" + 0.036*"사용" + 0.020*"제품" + 0.018*"태블릿" + 0.016*"보드" + 0.015*"입니다" + 0.014*"윈도우" + 0.012*"성능" + 0.011*"조금" + 0.010*"있는"
# Topic: 16
# Words: 0.052*"구매" + 0.047*"서피스" + 0.036*"사용" + 0.031*"제품" + 0.018*"생각" + 0.011*"만족합니다" + 0.011*"노트북" + 0.010*"메모리" + 0.010*"포트" + 0.010*"가격"
# Topic: 17
# Words: 0.025*"같아요" + 0.019*"좋고" + 0.019*"번창" + 0.019*"좋아요" + 0.019*"업그레이드" + 0.019*"사고" + 0.019*"프로" + 0.019*"만족합니다" + 0.019*"휴대" + 0.019*"성도"
# Topic: 18
# Words: 0.038*"사용" + 0.024*"입니다" + 0.024*"작업" + 0.023*"제품" + 0.023*"좋은" + 0.023*"기기" + 0.022*"활용" + 0.015*"생각" + 0.014*"보드" + 0.014*"구매"
# Topic: 19
# Words: 0.052*"좋아요" + 0.028*"윈도우" + 0.027*"있습니다" + 0.026*"완전" + 0.026*"태블릿" + 0.026*"만족" + 0.026*"바로" + 0.026*"빠르고" + 0.026*"터치" + 0.026*"다음"
# Topic: 20
# Words: 0.024*"사용" + 0.019*"입니다" + 0.019*"배송" + 0.016*"가격" + 0.012*"만족합니다" + 0.011*"드네" + 0.011*"활용" + 0.011*"고민" + 0.010*"생각" + 0.010*"성능"
# Topic: 21
# Words: 0.047*"사용" + 0.020*"구매" + 0.019*"노트북" + 0.018*"제품" + 0.017*"입니다" + 0.013*"좋습니다" + 0.012*"태블릿" + 0.011*"배송" + 0.010*"가격" + 0.010*"좋은"
# Topic: 22
# Words: 0.033*"휴대" + 0.028*"노트북" + 0.021*"아주" + 0.021*"듭니" + 0.021*"애매해서" + 0.021*"애매하긴한데" + 0.021*"관찮은것" + 0.021*"간편해서" + 0.021*"좋네요" + 0.021*"중간"
# Topic: 23
# Words: 0.055*"배송" + 0.045*"좋습니다" + 0.031*"빠른" + 0.023*"가격" + 0.023*"화질" + 0.023*"보드" + 0.023*"좋고" + 0.023*"이제" + 0.023*"만족스럽네요" + 0.023*"사용"
# Topic: 24
# Words: 0.036*"터치" + 0.036*"좋아요" + 0.036*"구매" + 0.018*"무게" + 0.018*"이하" + 0.018*"있었으며" + 0.018*"좋아겠습니다" + 0.018*"좋네요" + 0.018*"가동" + 0.018*"만족"
# Topic: 25
# Words: 0.050*"사용" + 0.037*"같아요" + 0.020*"배송" + 0.020*"좋습니다" + 0.020*"정말" + 0.019*"조금" + 0.011*"서피스" + 0.011*"고민" + 0.011*"없네요" + 0.010*"정도"
# Topic: 26
# Words: 0.021*"좋아요" + 0.020*"사용" + 0.018*"처음" + 0.018*"서피스" + 0.014*"보드" + 0.014*"편하고" + 0.014*"빨라요" + 0.014*"디자인" + 0.014*"생각" + 0.014*"좋아합니다"
# Topic: 27
# Words: 0.018*"고민" + 0.017*"성능" + 0.016*"구매" + 0.013*"마리" + 0.013*"토끼" + 0.012*"좋은" + 0.010*"윈도우" + 0.010*"전원" + 0.010*"가격" + 0.010*"디자인"
# Topic: 28
# Words: 0.020*"빠르고" + 0.019*"사용" + 0.016*"편하네요" + 0.016*"배송" + 0.016*"쓰기" + 0.013*"프로" + 0.012*"화면" + 0.012*"정도" + 0.011*"부분" + 0.010*"입니다"
# Topic: 29
# Words: 0.032*"성능" + 0.022*"고민" + 0.021*"좋아요" + 0.019*"추천" + 0.015*"화면" + 0.014*"서피스" + 0.013*"좋네요" + 0.013*"좋고" + 0.013*"예쁘고" + 0.013*"만족합니다"
# Topic: 30
# Words: 0.033*"구매" + 0.028*"사양" + 0.028*"가격" + 0.020*"고민" + 0.020*"좋은" + 0.016*"서피스프로" + 0.015*"사용" + 0.015*"배송" + 0.014*"노트북" + 0.012*"프로"
# Topic: 31
# Words: 0.027*"태블릿" + 0.026*"서피스" + 0.022*"프로" + 0.021*"필기" + 0.013*"좋은" + 0.013*"노트북" + 0.011*"기기" + 0.011*"선택" + 0.010*"보드" + 0.010*"작업"
# Topic: 32
# Words: 0.048*"만족합니다" + 0.038*"제품" + 0.029*"모델" + 0.029*"모두" + 0.026*"생각" + 0.026*"사용" + 0.019*"문제" + 0.019*"좋아요" + 0.019*"입니다" + 0.017*"화면"
# Topic: 33
# Words: 0.043*"배송" + 0.035*"서피스" + 0.034*"빠르고" + 0.033*"사용" + 0.028*"입니다" + 0.024*"노트북" + 0.023*"제품" + 0.019*"정말" + 0.018*"프로" + 0.014*"좋네요"
# Topic: 34
# Words: 0.047*"배송" + 0.040*"서비스" + 0.038*"구매" + 0.021*"사용" + 0.018*"좋네요" + 0.017*"업무" + 0.015*"있습니다" + 0.013*"서피스" + 0.012*"오피스" + 0.011*"사무실"
# Topic: 35
# Words: 0.028*"만족합니다" + 0.028*"부분" + 0.028*"입니다" + 0.028*"구매" + 0.028*"노트북" + 0.014*"실용" + 0.014*"확장" + 0.014*"오피스" + 0.014*"업무" + 0.014*"좋아요"
# Topic: 36
# Words: 0.033*"구매" + 0.024*"좋네요" + 0.024*"서피스" + 0.024*"선물" + 0.024*"엄마" + 0.024*"사용" + 0.020*"기분" + 0.012*"취미" + 0.012*"원하시는" + 0.012*"아주"
# Topic: 37
# Words: 0.053*"사용" + 0.050*"있습니다" + 0.029*"정말" + 0.029*"노트북" + 0.029*"제품" + 0.029*"배송" + 0.020*"입니다" + 0.016*"서피스" + 0.014*"딱이에요" + 0.014*"휴대"
# Topic: 38
# Words: 0.039*"사용" + 0.034*"있습니다" + 0.030*"최고" + 0.023*"프로" + 0.023*"서피스" + 0.020*"업무" + 0.019*"제품" + 0.014*"포장" + 0.013*"배송" + 0.010*"도착"
# Topic: 39
# Words: 0.037*"태블릿" + 0.035*"노트북" + 0.026*"가격" + 0.025*"구매" + 0.021*"도착" + 0.018*"보드" + 0.017*"조금" + 0.016*"택배" + 0.016*"어제" + 0.016*"제품"
# Topic: 40
# Words: 0.033*"만족합니다" + 0.033*"올해" + 0.033*"제일" + 0.033*"소비" + 0.033*"이용" + 0.033*"발열" + 0.033*"약간" + 0.033*"있지만" + 0.000*"사지" + 0.000*"여기저기"
# Topic: 41
# Words: 0.086*"배송" + 0.049*"빠르고" + 0.049*"빠른" + 0.024*"편하고" + 0.024*"주문" + 0.024*"노트북" + 0.024*"어제" + 0.024*"인상" + 0.024*"만족스럽습니다" + 0.024*"서피스"
# Topic: 42
# Words: 0.034*"같습니다" + 0.034*"역시" + 0.034*"저렴하게" + 0.020*"사용" + 0.016*"베터리" + 0.014*"준수" + 0.013*"좋다고" + 0.013*"주문" + 0.012*"외근" + 0.011*"시간"
# Topic: 43
# Words: 0.027*"생각" + 0.026*"마음" + 0.022*"서피스" + 0.019*"좋은" + 0.018*"작업" + 0.018*"포트" + 0.017*"충전" + 0.017*"듭니" + 0.017*"만족합니다" + 0.017*"충전기"
# Topic: 44
# Words: 0.063*"배송" + 0.031*"빠른" + 0.026*"서피스" + 0.025*"사용" + 0.016*"좋습니다" + 0.016*"최고" + 0.014*"이제" + 0.013*"처음" + 0.012*"모델" + 0.011*"빠르고"
# Topic: 45
# Words: 0.045*"배송" + 0.035*"구매" + 0.029*"서피스" + 0.028*"필름" + 0.017*"사은" + 0.017*"원하는" + 0.017*"상대" + 0.017*"성하네요" + 0.017*"빠릅니다" + 0.017*"높습니다"
# Topic: 46
# Words: 0.032*"좋은" + 0.031*"코어" + 0.029*"가격" + 0.029*"있습니다" + 0.023*"노트북" + 0.022*"사용" + 0.015*"편합니다" + 0.015*"좋네요" + 0.015*"만족합니다" + 0.015*"어설픈"
# Topic: 47
# Words: 0.026*"사용" + 0.022*"입니다" + 0.021*"서피스프로" + 0.014*"무게" + 0.013*"정도" + 0.013*"프로" + 0.012*"보드" + 0.012*"화면" + 0.011*"느낌" + 0.010*"작업"
# Topic: 48
# Words: 0.025*"배송" + 0.025*"만족스럽습니다" + 0.025*"태블릿" + 0.025*"서피스" + 0.025*"좋아요" + 0.025*"빠르고" + 0.025*"제품" + 0.012*"편리해요" + 0.012*"고민" + 0.012*"주문"
# Topic: 49
# Words: 0.044*"이뻐요" + 0.022*"필기" + 0.022*"좋아여" + 0.022*"좋습니다" + 0.022*"아니니" + 0.022*"애매합니다" + 0.022*"야할까" + 0.022*"좋고" + 0.022*"인식" + 0.022*"안되는"
# Topic: 50
# Words: 0.040*"사용" + 0.034*"서피스" + 0.017*"좋습니다" + 0.015*"노트북" + 0.015*"입니다" + 0.015*"디자인" + 0.014*"있습니다" + 0.014*"배송" + 0.011*"프로" + 0.011*"다만"
# Topic: 51
# Words: 0.047*"프로" + 0.045*"서피스" + 0.032*"사용" + 0.028*"만족스럽습니다" + 0.028*"배송" + 0.024*"노트북" + 0.019*"코어" + 0.014*"없네요" + 0.014*"구매" + 0.014*"발열"
# Topic: 52
# Words: 0.043*"만족합니다" + 0.034*"구매" + 0.031*"배송" + 0.024*"문제" + 0.017*"서피스프로" + 0.016*"입니다" + 0.015*"사용" + 0.015*"가격" + 0.014*"제품" + 0.013*"좋습니다"
# Topic: 53
# Words: 0.034*"생각" + 0.034*"마음" + 0.034*"서피스" + 0.034*"처음" + 0.034*"구매" + 0.034*"프로" + 0.034*"듭니" + 0.000*"신뢰" + 0.000*"편했거든요" + 0.000*"사지"
# Topic: 54
# Words: 0.045*"사용" + 0.044*"최고" + 0.023*"구매" + 0.022*"입니다" + 0.022*"마음" + 0.022*"생산" + 0.022*"휴대" + 0.022*"무용" + 0.022*"노트북" + 0.022*"터치"
# Topic: 55
# Words: 0.033*"가격" + 0.033*"사용" + 0.022*"구매" + 0.022*"부착" + 0.022*"배송" + 0.022*"개봉" + 0.022*"기능" + 0.022*"안전하게" + 0.011*"휴대폰" + 0.011*"갤럭시"
# Topic: 56
# Words: 0.069*"좋네요" + 0.043*"배송" + 0.035*"사용" + 0.035*"색상" + 0.017*"훅훅" + 0.017*"우선" + 0.017*"구입" + 0.017*"서브" + 0.017*"가끔" + 0.017*"깔끔하고"
# Topic: 57
# Words: 0.066*"사용" + 0.033*"구매" + 0.030*"서피스" + 0.025*"이번" + 0.017*"좋네요" + 0.012*"프로" + 0.012*"노트북" + 0.011*"편하게" + 0.010*"있습니다" + 0.010*"있어요"
# Topic: 58
# Words: 0.047*"서피스" + 0.031*"제품" + 0.022*"배송" + 0.022*"빠른" + 0.016*"완성" + 0.016*"만족스럽습니다" + 0.016*"확장" + 0.016*"성능" + 0.016*"필요하신" + 0.016*"같습니다"
# Topic: 59
# Words: 0.040*"사용" + 0.020*"테블릿" + 0.020*"정도" + 0.020*"안심" + 0.020*"만족스럽네요" + 0.020*"성능" + 0.020*"좋아요" + 0.020*"다만" + 0.020*"어렵습니다" + 0.020*"노트북"
# Topic: 60
# Words: 0.027*"휴대" + 0.025*"좋은" + 0.025*"생각" + 0.019*"배송" + 0.019*"좋습니다" + 0.018*"제품" + 0.018*"입니다" + 0.013*"만족스럽습니다" + 0.013*"시작" + 0.013*"일요일"
# Topic: 61
# Words: 0.039*"서피스" + 0.038*"사용" + 0.031*"제품" + 0.030*"구매" + 0.023*"프로" + 0.016*"이번" + 0.016*"생각" + 0.014*"있는" + 0.012*"노트북" + 0.012*"다음"
# Topic: 62
# Words: 0.027*"사용" + 0.026*"계속" + 0.026*"고민" + 0.022*"서피스" + 0.014*"좋은" + 0.014*"성능" + 0.014*"출장" + 0.014*"이상" + 0.013*"노트북" + 0.013*"역시"
# Topic: 63
# Words: 0.045*"사용" + 0.030*"무엇" + 0.030*"성능" + 0.030*"좋고" + 0.015*"매우" + 0.015*"입니다" + 0.015*"업무" + 0.015*"같아요" + 0.015*"만족합니다" + 0.015*"좋네요"
# Topic: 64
# Words: 0.032*"사용" + 0.021*"서피스" + 0.020*"같습니다" + 0.020*"좋습니다" + 0.020*"업무" + 0.020*"스탠드" + 0.020*"있는거" + 0.020*"착학" + 0.020*"간단한" + 0.020*"높네요"
# Topic: 65
# Words: 0.039*"제품" + 0.026*"좋습니다" + 0.025*"서피스" + 0.018*"입니다" + 0.015*"프로" + 0.014*"가격" + 0.012*"태블릿" + 0.012*"구매" + 0.011*"메인" + 0.011*"좋은"
# Topic: 66
# Words: 0.061*"만족합니다" + 0.031*"서피스" + 0.031*"배송" + 0.031*"가지" + 0.031*"빠르고" + 0.031*"기능" + 0.031*"노트북" + 0.031*"필요없어요" + 0.031*"타블릿" + 0.000*"여기저기"
# Topic: 67
# Words: 0.022*"프로" + 0.020*"후회" + 0.020*"구입" + 0.020*"보드" + 0.020*"마음" + 0.016*"생각" + 0.016*"고민" + 0.016*"정말" + 0.015*"가격" + 0.015*"노트북"
# Topic: 68
# Words: 0.037*"정말" + 0.037*"배송" + 0.031*"빠른" + 0.028*"좋습니다" + 0.022*"사용" + 0.022*"제품" + 0.022*"좋네요" + 0.018*"좋아요" + 0.018*"빠르고" + 0.018*"고민"
# Topic: 69
# Words: 0.029*"휴대" + 0.028*"서피스" + 0.025*"노트북" + 0.022*"사용" + 0.021*"구매" + 0.017*"입니다" + 0.016*"같습니다" + 0.015*"프로" + 0.012*"좋은" + 0.010*"최고"
# Topic: 70
# Words: 0.040*"있습니다" + 0.030*"사용" + 0.020*"태블릿" + 0.017*"제품" + 0.017*"구매" + 0.017*"문제" + 0.016*"좋아요" + 0.016*"좋습니다" + 0.016*"만족" + 0.016*"상품"
# Topic: 71
# Words: 0.024*"빨강" + 0.023*"보드" + 0.022*"서피스프로" + 0.022*"모델" + 0.022*"좋은" + 0.021*"입니다" + 0.012*"사용" + 0.012*"있어요" + 0.012*"퍼럼도" + 0.012*"아주"
# Topic: 72
# Words: 0.050*"사용" + 0.038*"서피스" + 0.032*"구매" + 0.019*"노트북" + 0.019*"프로" + 0.015*"있습니다" + 0.014*"좋습니다" + 0.014*"제품" + 0.014*"입니다" + 0.010*"생각"
# Topic: 73
# Words: 0.036*"사용" + 0.031*"최고" + 0.027*"배송" + 0.027*"저렴하게" + 0.019*"서피스" + 0.018*"아주" + 0.017*"항상" + 0.014*"침대" + 0.014*"작별인사" + 0.014*"전이"
# Topic: 74
# Words: 0.022*"그린" + 0.022*"프로" + 0.021*"정도" + 0.018*"가격" + 0.017*"보드" + 0.017*"가벼워서" + 0.017*"만족합니다" + 0.015*"구입" + 0.012*"사용" + 0.011*"편하네요"
# Topic: 75
# Words: 0.060*"노트북" + 0.018*"같은" + 0.016*"드래그" + 0.014*"가장" + 0.013*"처음" + 0.013*"대학생" + 0.012*"사용" + 0.011*"있어요" + 0.011*"터치패드" + 0.011*"구매"
# Topic: 76
# Words: 0.030*"좋습니다" + 0.014*"사용" + 0.013*"패드" + 0.012*"프로그램" + 0.012*"윈도우" + 0.011*"가능한" + 0.010*"마이크로소프트" + 0.010*"욕심" + 0.009*"진짜" + 0.008*"제품"
# Topic: 77
# Words: 0.039*"사용" + 0.039*"제품" + 0.026*"좋아요" + 0.022*"배송" + 0.021*"윈도우" + 0.019*"디자인" + 0.019*"빠른" + 0.018*"발열" + 0.016*"있어서" + 0.016*"생각"
# Topic: 78
# Words: 0.039*"사용" + 0.026*"아이패드" + 0.020*"구매" + 0.016*"사이즈" + 0.016*"문서" + 0.013*"작업" + 0.013*"같아요" + 0.013*"개발" + 0.013*"물건" + 0.013*"이제"
# Topic: 79
# Words: 0.032*"사용" + 0.026*"구매" + 0.024*"가볍고" + 0.024*"용도" + 0.024*"배송" + 0.019*"좋아요" + 0.016*"있어서" + 0.016*"윈도우" + 0.016*"좋고" + 0.016*"휴대"
# Topic: 80
# Words: 0.037*"배송" + 0.021*"빠르고" + 0.019*"사용" + 0.019*"보호" + 0.019*"필름" + 0.017*"생각" + 0.016*"무게" + 0.015*"태블릿" + 0.014*"있지만" + 0.011*"서피스프로"
# Topic: 81
# Words: 0.040*"사용" + 0.031*"구매" + 0.027*"서피스" + 0.024*"제품" + 0.021*"배송" + 0.018*"빠르고" + 0.014*"서피스프로" + 0.013*"이번" + 0.013*"매우" + 0.013*"노트북"
# Topic: 82
# Words: 0.033*"서피스" + 0.023*"사용" + 0.014*"제품" + 0.013*"보기" + 0.013*"프로" + 0.013*"구매" + 0.011*"문서" + 0.010*"평가" + 0.009*"추가" + 0.009*"필름"
# Topic: 83
# Words: 0.036*"제품" + 0.036*"사용" + 0.028*"매우" + 0.027*"노트북" + 0.027*"태블릿" + 0.019*"구매" + 0.018*"최적화" + 0.018*"두루" + 0.018*"있습니다" + 0.018*"고급"
# Topic: 84
# Words: 0.026*"태블릿" + 0.023*"윈도우" + 0.022*"가격" + 0.021*"배송" + 0.020*"노트북" + 0.019*"고민" + 0.017*"구매" + 0.015*"모두" + 0.013*"작업" + 0.012*"있습니다"
# Topic: 85
# Words: 0.041*"좋아요" + 0.021*"컴퓨터" + 0.021*"주문" + 0.021*"재질" + 0.021*"도착" + 0.021*"사용성" + 0.021*"어제" + 0.021*"있고" + 0.021*"필요해서" + 0.021*"촉감"
# Topic: 86
# Words: 0.031*"사용" + 0.030*"서피스" + 0.020*"노트북" + 0.020*"구매" + 0.018*"업무" + 0.016*"모델" + 0.016*"배송" + 0.015*"프로그램" + 0.012*"태블릿" + 0.011*"성능"
# Topic: 87
# Words: 0.029*"빠르고" + 0.029*"가격" + 0.029*"이번" + 0.029*"좋네요" + 0.029*"선물" + 0.015*"휴대" + 0.015*"구매" + 0.015*"좋았습니다" + 0.015*"살수" + 0.015*"착해서"
# Topic: 88
# Words: 0.046*"가볍고" + 0.023*"태블릿" + 0.023*"이뻐요" + 0.023*"배송" + 0.023*"좋네요" + 0.023*"좋습니다" + 0.023*"노트북" + 0.023*"물건" + 0.023*"처음" + 0.023*"빠른"
# Topic: 89
# Words: 0.041*"사용" + 0.038*"좋은" + 0.033*"구매" + 0.028*"좋아요" + 0.020*"제품" + 0.020*"추천" + 0.019*"가격" + 0.019*"정말" + 0.019*"태블릿" + 0.019*"가볍고"
# Topic: 90
# Words: 0.023*"입니다" + 0.016*"세로" + 0.015*"작업" + 0.015*"보드" + 0.014*"아주" + 0.014*"구입" + 0.013*"모드" + 0.011*"노트북" + 0.011*"서피스프로" + 0.011*"사용"
# Topic: 91
# Words: 0.042*"좋아요" + 0.030*"배송" + 0.024*"입니다" + 0.024*"서피스" + 0.021*"빠르고" + 0.020*"사용" + 0.019*"휴대" + 0.018*"고민" + 0.017*"환경" + 0.017*"구매"
# Topic: 92
# Words: 0.025*"사용" + 0.023*"서피스프로" + 0.020*"배터리" + 0.018*"서피스" + 0.018*"배송" + 0.018*"같습니다" + 0.016*"좋아요" + 0.013*"윈도우" + 0.013*"빠르고" + 0.011*"프로그램"
# Topic: 93
# Words: 0.025*"구매" + 0.025*"배송" + 0.025*"업무" + 0.019*"사용" + 0.018*"프로" + 0.016*"기기" + 0.016*"문제" + 0.015*"무게" + 0.014*"태블릿" + 0.014*"서피스"
# Topic: 94
# Words: 0.024*"저렴하게" + 0.024*"구매" + 0.023*"매우" + 0.018*"만족" + 0.017*"제품" + 0.015*"부분" + 0.013*"있는" + 0.012*"입니다" + 0.012*"마감" + 0.012*"좋아요"
# Topic: 95
# Words: 0.026*"사용" + 0.026*"제품" + 0.020*"입니다" + 0.017*"구매" + 0.016*"고민" + 0.015*"보드" + 0.015*"태블릿" + 0.014*"가격" + 0.013*"좋은" + 0.011*"노트북"
# Topic: 96
# Words: 0.031*"입니다" + 0.028*"아주" + 0.028*"최고" + 0.023*"역시" + 0.020*"정말" + 0.018*"매우" + 0.017*"서피스" + 0.016*"제품" + 0.014*"아닐까" + 0.014*"듭니"
# Topic: 97
# Words: 0.045*"노트북" + 0.040*"사용" + 0.040*"서피스" + 0.029*"프로" + 0.017*"정말" + 0.017*"태블릿" + 0.017*"배송" + 0.017*"상품" + 0.016*"좋은" + 0.016*"입니다"
# Topic: 98
# Words: 0.030*"사용" + 0.026*"부분" + 0.021*"서피스" + 0.017*"색상" + 0.015*"업무" + 0.015*"같습니다" + 0.015*"추천" + 0.014*"매우" + 0.014*"있는" + 0.013*"같아"
# Topic: 99
# Words: 0.079*"사용" + 0.037*"작동" + 0.032*"서피스" + 0.022*"기존" + 0.022*"정상" + 0.021*"오피스" + 0.020*"보드" + 0.016*"좋아요" + 0.016*"슬림펜" + 0.016*"만족합니다"
#
# 부정적 리뷰의 주제:
# Topic: 0
# Words: 0.002*"향상" + 0.002*"가량" + 0.002*"재생" + 0.002*"정확도" + 0.002*"터치" + 0.002*"테스트" + 0.002*"필요할거고" + 0.002*"용감" + 0.002*"환경" + 0.002*"만족스럽니다"
# Topic: 1
# Words: 0.002*"향상" + 0.002*"가량" + 0.002*"재생" + 0.002*"정확도" + 0.002*"터치" + 0.002*"테스트" + 0.002*"필요할거고" + 0.002*"용감" + 0.002*"환경" + 0.002*"만족스럽니다"
# Topic: 2
# Words: 0.002*"향상" + 0.002*"가량" + 0.002*"재생" + 0.002*"정확도" + 0.002*"터치" + 0.002*"테스트" + 0.002*"필요할거고" + 0.002*"용감" + 0.002*"환경" + 0.002*"만족스럽니다"
# Topic: 3
# Words: 0.002*"향상" + 0.002*"가량" + 0.002*"재생" + 0.002*"정확도" + 0.002*"터치" + 0.002*"테스트" + 0.002*"필요할거고" + 0.002*"용감" + 0.002*"환경" + 0.002*"만족스럽니다"
# Topic: 4
# Words: 0.059*"훌륭합니다" + 0.059*"스펙" + 0.059*"디자인" + 0.059*"무겁습니다만" + 0.059*"약간" + 0.037*"기간" + 0.034*"정가" + 0.032*"작업" + 0.032*"할인" + 0.029*"있어서"
# Topic: 5
# Words: 0.048*"서피스" + 0.032*"노트북" + 0.031*"구매" + 0.020*"제품" + 0.020*"사용" + 0.017*"입니다" + 0.016*"사은" + 0.015*"휴대" + 0.013*"기대" + 0.012*"장점"
# Topic: 6
# Words: 0.120*"같아요" + 0.120*"후기" + 0.120*"보고" + 0.001*"가량" + 0.001*"재생" + 0.001*"정확도" + 0.001*"터치" + 0.001*"테스트" + 0.001*"필요할거고" + 0.001*"용감"
# Topic: 7
# Words: 0.024*"프로" + 0.021*"사용" + 0.021*"입니다" + 0.018*"기기" + 0.016*"같아요" + 0.016*"화면" + 0.015*"성은" + 0.014*"무게" + 0.014*"아주" + 0.014*"이건"
# Topic: 8
# Words: 0.049*"환경" + 0.031*"문제" + 0.030*"용감" + 0.030*"사운드" + 0.029*"때문" + 0.028*"마이크" + 0.017*"입니다" + 0.017*"기능" + 0.016*"스피커" + 0.016*"서피스프로"
# Topic: 9
# Words: 0.028*"이전" + 0.025*"포장" + 0.023*"부분" + 0.023*"맥북" + 0.023*"입니다" + 0.021*"제품" + 0.020*"서피스" + 0.019*"사용" + 0.018*"택배" + 0.013*"있겠습니다"
# Topic: 10
# Words: 0.002*"향상" + 0.002*"가량" + 0.002*"재생" + 0.002*"정확도" + 0.002*"터치" + 0.002*"테스트" + 0.002*"필요할거고" + 0.002*"용감" + 0.002*"환경" + 0.002*"만족스럽니다"
# Topic: 11
# Words: 0.103*"색상" + 0.103*"성능" + 0.052*"부족함" + 0.052*"아이패드" + 0.052*"안되는" + 0.052*"선택" + 0.052*"가볍게" + 0.052*"없는" + 0.052*"건가" + 0.052*"업데이트"
# Topic: 12
# Words: 0.002*"향상" + 0.002*"가량" + 0.002*"재생" + 0.002*"정확도" + 0.002*"터치" + 0.002*"테스트" + 0.002*"필요할거고" + 0.002*"용감" + 0.002*"환경" + 0.002*"만족스럽니다"
# Topic: 13
# Words: 0.002*"향상" + 0.002*"가량" + 0.002*"재생" + 0.002*"정확도" + 0.002*"터치" + 0.002*"테스트" + 0.002*"필요할거고" + 0.002*"용감" + 0.002*"환경" + 0.002*"만족스럽니다"
# Topic: 14
# Words: 0.120*"추천" + 0.120*"좋은" + 0.120*"같네요" + 0.001*"필요할거고" + 0.001*"재생" + 0.001*"정확도" + 0.001*"터치" + 0.001*"테스트" + 0.001*"이하" + 0.001*"고개"
# Topic: 15
# Words: 0.002*"향상" + 0.002*"가량" + 0.002*"재생" + 0.002*"정확도" + 0.002*"터치" + 0.002*"테스트" + 0.002*"필요할거고" + 0.002*"용감" + 0.002*"환경" + 0.002*"만족스럽니다"
# Topic: 16
# Words: 0.002*"향상" + 0.002*"가량" + 0.002*"재생" + 0.002*"정확도" + 0.002*"터치" + 0.002*"테스트" + 0.002*"필요할거고" + 0.002*"용감" + 0.002*"환경" + 0.002*"만족스럽니다"
# Topic: 17
# Words: 0.002*"향상" + 0.002*"가량" + 0.002*"재생" + 0.002*"정확도" + 0.002*"터치" + 0.002*"테스트" + 0.002*"필요할거고" + 0.002*"용감" + 0.002*"환경" + 0.002*"만족스럽니다"
# Topic: 18
# Words: 0.016*"입니다" + 0.013*"사용" + 0.012*"성은" + 0.012*"이건" + 0.011*"아주" + 0.011*"무게" + 0.011*"기존" + 0.011*"상당히" + 0.010*"서피스프로" + 0.010*"프로"
# Topic: 19
# Words: 0.049*"센터" + 0.042*"고객" + 0.040*"전화" + 0.033*"리턴" + 0.024*"손상" + 0.023*"프리" + 0.023*"답변" + 0.020*"시리얼" + 0.018*"청구" + 0.018*"덕분"
# Topic: 20
# Words: 0.157*"생각" + 0.002*"향상" + 0.002*"가량" + 0.002*"재생" + 0.002*"정확도" + 0.002*"터치" + 0.002*"테스트" + 0.002*"필요할거고" + 0.002*"용감" + 0.002*"마소"
# Topic: 21
# Words: 0.002*"향상" + 0.002*"가량" + 0.002*"재생" + 0.002*"정확도" + 0.002*"터치" + 0.002*"테스트" + 0.002*"필요할거고" + 0.002*"용감" + 0.002*"환경" + 0.002*"만족스럽니다"
# Topic: 22
# Words: 0.002*"향상" + 0.002*"가량" + 0.002*"재생" + 0.002*"정확도" + 0.002*"터치" + 0.002*"테스트" + 0.002*"필요할거고" + 0.002*"용감" + 0.002*"환경" + 0.002*"만족스럽니다"
# Topic: 23
# Words: 0.120*"이상" + 0.120*"사용" + 0.120*"입니다" + 0.001*"향상" + 0.001*"재생" + 0.001*"정확도" + 0.001*"터치" + 0.001*"테스트" + 0.001*"필요할거고" + 0.001*"이하"
# Topic: 24
# Words: 0.103*"제품" + 0.103*"사용" + 0.052*"윈더" + 0.052*"성능" + 0.052*"없어오" + 0.052*"이만" + 0.052*"이번" + 0.052*"프로" + 0.052*"서피스" + 0.052*"구매"
# Topic: 25
# Words: 0.002*"향상" + 0.002*"가량" + 0.002*"재생" + 0.002*"정확도" + 0.002*"터치" + 0.002*"테스트" + 0.002*"필요할거고" + 0.002*"용감" + 0.002*"환경" + 0.002*"만족스럽니다"
# Topic: 26
# Words: 0.002*"향상" + 0.002*"가량" + 0.002*"재생" + 0.002*"정확도" + 0.002*"터치" + 0.002*"테스트" + 0.002*"필요할거고" + 0.002*"용감" + 0.002*"환경" + 0.002*"만족스럽니다"
# Topic: 27
# Words: 0.036*"입니다" + 0.029*"배송" + 0.029*"마감" + 0.029*"매우" + 0.022*"저렴하게" + 0.021*"사용" + 0.019*"프로" + 0.017*"좋았습니다" + 0.017*"빠르고" + 0.017*"양품"
# Topic: 28
# Words: 0.002*"향상" + 0.002*"가량" + 0.002*"재생" + 0.002*"정확도" + 0.002*"터치" + 0.002*"테스트" + 0.002*"필요할거고" + 0.002*"용감" + 0.002*"환경" + 0.002*"만족스럽니다"
# Topic: 29
# Words: 0.002*"향상" + 0.002*"가량" + 0.002*"재생" + 0.002*"정확도" + 0.002*"터치" + 0.002*"테스트" + 0.002*"필요할거고" + 0.002*"용감" + 0.002*"환경" + 0.002*"만족스럽니다"
# Topic: 30
# Words: 0.002*"향상" + 0.002*"가량" + 0.002*"재생" + 0.002*"정확도" + 0.002*"터치" + 0.002*"테스트" + 0.002*"필요할거고" + 0.002*"용감" + 0.002*"환경" + 0.002*"만족스럽니다"
# Topic: 31
# Words: 0.002*"향상" + 0.002*"가량" + 0.002*"재생" + 0.002*"정확도" + 0.002*"터치" + 0.002*"테스트" + 0.002*"필요할거고" + 0.002*"용감" + 0.002*"환경" + 0.002*"만족스럽니다"
# Topic: 32
# Words: 0.039*"사용" + 0.039*"터치" + 0.038*"가벼운" + 0.034*"분할" + 0.034*"나름" + 0.034*"가동" + 0.034*"있었으며" + 0.034*"좋아겠습니다" + 0.034*"하드" + 0.034*"작다"
# Topic: 33
# Words: 0.002*"향상" + 0.002*"가량" + 0.002*"재생" + 0.002*"정확도" + 0.002*"터치" + 0.002*"테스트" + 0.002*"필요할거고" + 0.002*"용감" + 0.002*"환경" + 0.002*"만족스럽니다"
# Topic: 34
# Words: 0.002*"향상" + 0.002*"가량" + 0.002*"재생" + 0.002*"정확도" + 0.002*"터치" + 0.002*"테스트" + 0.002*"필요할거고" + 0.002*"용감" + 0.002*"환경" + 0.002*"만족스럽니다"
# Topic: 35
# Words: 0.002*"향상" + 0.002*"가량" + 0.002*"재생" + 0.002*"정확도" + 0.002*"터치" + 0.002*"테스트" + 0.002*"필요할거고" + 0.002*"용감" + 0.002*"환경" + 0.002*"만족스럽니다"
# Topic: 36
# Words: 0.002*"향상" + 0.002*"가량" + 0.002*"재생" + 0.002*"정확도" + 0.002*"터치" + 0.002*"테스트" + 0.002*"필요할거고" + 0.002*"용감" + 0.002*"환경" + 0.002*"만족스럽니다"
# Topic: 37
# Words: 0.080*"가격" + 0.057*"다만" + 0.056*"제품" + 0.054*"정말" + 0.054*"좋고" + 0.054*"사전예약" + 0.028*"같습니다" + 0.028*"가량" + 0.028*"주일" + 0.027*"마소"
# Topic: 38
# Words: 0.061*"입니다" + 0.061*"마감" + 0.061*"프로그램" + 0.061*"정식" + 0.061*"구동" + 0.061*"괜찮은데" + 0.061*"좋고" + 0.061*"안드로이드" + 0.061*"어렵네요" + 0.061*"좋겠네요"
# Topic: 39
# Words: 0.067*"서피스" + 0.031*"구매" + 0.027*"사용" + 0.023*"노트북" + 0.023*"제품" + 0.021*"입니다" + 0.015*"이전" + 0.013*"사은" + 0.012*"택배" + 0.012*"고려"
# Topic: 40
# Words: 0.002*"향상" + 0.002*"가량" + 0.002*"재생" + 0.002*"정확도" + 0.002*"터치" + 0.002*"테스트" + 0.002*"필요할거고" + 0.002*"용감" + 0.002*"환경" + 0.002*"만족스럽니다"
# Topic: 41
# Words: 0.002*"향상" + 0.002*"가량" + 0.002*"재생" + 0.002*"정확도" + 0.002*"터치" + 0.002*"테스트" + 0.002*"필요할거고" + 0.002*"용감" + 0.002*"환경" + 0.002*"만족스럽니다"
# Topic: 42
# Words: 0.002*"향상" + 0.002*"가량" + 0.002*"재생" + 0.002*"정확도" + 0.002*"터치" + 0.002*"테스트" + 0.002*"필요할거고" + 0.002*"용감" + 0.002*"환경" + 0.002*"만족스럽니다"
# Topic: 43
# Words: 0.002*"향상" + 0.002*"가량" + 0.002*"재생" + 0.002*"정확도" + 0.002*"터치" + 0.002*"테스트" + 0.002*"필요할거고" + 0.002*"용감" + 0.002*"환경" + 0.002*"만족스럽니다"
# Topic: 44
# Words: 0.002*"향상" + 0.002*"가량" + 0.002*"재생" + 0.002*"정확도" + 0.002*"터치" + 0.002*"테스트" + 0.002*"필요할거고" + 0.002*"용감" + 0.002*"환경" + 0.002*"만족스럽니다"
# Topic: 45
# Words: 0.030*"이전" + 0.021*"택배" + 0.020*"제품" + 0.018*"사용" + 0.018*"서피스" + 0.016*"맥북" + 0.016*"입니다" + 0.016*"포장" + 0.013*"배젤" + 0.013*"부분"
# Topic: 46
# Words: 0.002*"향상" + 0.002*"가량" + 0.002*"재생" + 0.002*"정확도" + 0.002*"터치" + 0.002*"테스트" + 0.002*"필요할거고" + 0.002*"용감" + 0.002*"환경" + 0.002*"만족스럽니다"
# Topic: 47
# Words: 0.002*"향상" + 0.002*"가량" + 0.002*"재생" + 0.002*"정확도" + 0.002*"터치" + 0.002*"테스트" + 0.002*"필요할거고" + 0.002*"용감" + 0.002*"환경" + 0.002*"만족스럽니다"
# Topic: 48
# Words: 0.002*"향상" + 0.002*"가량" + 0.002*"재생" + 0.002*"정확도" + 0.002*"터치" + 0.002*"테스트" + 0.002*"필요할거고" + 0.002*"용감" + 0.002*"환경" + 0.002*"만족스럽니다"
# Topic: 49
# Words: 0.002*"향상" + 0.002*"가량" + 0.002*"재생" + 0.002*"정확도" + 0.002*"터치" + 0.002*"테스트" + 0.002*"필요할거고" + 0.002*"용감" + 0.002*"환경" + 0.002*"만족스럽니다"
# Topic: 50
# Words: 0.057*"서피스" + 0.055*"구매" + 0.025*"노트북" + 0.021*"사용" + 0.019*"입니다" + 0.019*"비싼" + 0.018*"고려" + 0.018*"휴대" + 0.017*"제품" + 0.015*"사은"
# Topic: 51
# Words: 0.002*"향상" + 0.002*"가량" + 0.002*"재생" + 0.002*"정확도" + 0.002*"터치" + 0.002*"테스트" + 0.002*"필요할거고" + 0.002*"용감" + 0.002*"환경" + 0.002*"만족스럽니다"
# Topic: 52
# Words: 0.081*"터치" + 0.081*"배송" + 0.081*"안되는것" + 0.081*"빠릅니다" + 0.081*"만족스럽다" + 0.081*"인식" + 0.081*"같아요" + 0.001*"재생" + 0.001*"정확도" + 0.001*"테스트"
# Topic: 53
# Words: 0.120*"서피스" + 0.120*"좋죠" + 0.120*"사용성" + 0.001*"필요할거고" + 0.001*"환경" + 0.001*"정확도" + 0.001*"터치" + 0.001*"테스트" + 0.001*"이하" + 0.001*"향상"
# Topic: 54
# Words: 0.075*"가격" + 0.075*"좋은" + 0.075*"높긴" + 0.075*"노트북" + 0.075*"만족합니다" + 0.075*"해도" + 0.075*"윈도우" + 0.075*"호환성" + 0.001*"환경" + 0.001*"터치"
# Topic: 55
# Words: 0.002*"향상" + 0.002*"가량" + 0.002*"재생" + 0.002*"정확도" + 0.002*"터치" + 0.002*"테스트" + 0.002*"필요할거고" + 0.002*"용감" + 0.002*"환경" + 0.002*"만족스럽니다"
# Topic: 56
# Words: 0.107*"보드" + 0.107*"빨라요" + 0.107*"만족스럽네요" + 0.107*"배송" + 0.001*"테스트" + 0.001*"향상" + 0.001*"재생" + 0.001*"정확도" + 0.001*"터치" + 0.001*"용감"
# Topic: 57
# Words: 0.058*"구매" + 0.058*"태블릿" + 0.058*"보드" + 0.058*"배송" + 0.058*"퍼포먼스" + 0.058*"윈도우" + 0.058*"포장" + 0.058*"쿠션" + 0.058*"별도" + 0.058*"광속"
# Topic: 58
# Words: 0.024*"사용" + 0.023*"프로" + 0.023*"입니다" + 0.018*"정도" + 0.016*"무게" + 0.016*"상당히" + 0.015*"아주" + 0.015*"화면" + 0.015*"성은" + 0.014*"이건"
# Topic: 59
# Words: 0.070*"사용" + 0.070*"오피스" + 0.070*"볼때" + 0.070*"업무" + 0.070*"좋네요" + 0.070*"여행" + 0.070*"해외" + 0.070*"있어서" + 0.070*"가볍게" + 0.001*"테스트"
# Topic: 60
# Words: 0.017*"프로" + 0.016*"입니다" + 0.014*"서피스프로" + 0.013*"정도" + 0.012*"기존" + 0.012*"아주" + 0.012*"상당히" + 0.012*"기기" + 0.012*"같아요" + 0.011*"화면"
# Topic: 61
# Words: 0.002*"향상" + 0.002*"가량" + 0.002*"재생" + 0.002*"정확도" + 0.002*"터치" + 0.002*"테스트" + 0.002*"필요할거고" + 0.002*"용감" + 0.002*"환경" + 0.002*"만족스럽니다"
# Topic: 62
# Words: 0.002*"향상" + 0.002*"가량" + 0.002*"재생" + 0.002*"정확도" + 0.002*"터치" + 0.002*"테스트" + 0.002*"필요할거고" + 0.002*"용감" + 0.002*"환경" + 0.002*"만족스럽니다"
# Topic: 63
# Words: 0.075*"서피스" + 0.075*"처음" + 0.075*"좋습니다" + 0.075*"좋네요" + 0.075*"업무" + 0.075*"사용" + 0.075*"무거운" + 0.075*"사무" + 0.001*"사전예약" + 0.001*"환경"
# Topic: 64
# Words: 0.002*"아주" + 0.002*"사용" + 0.002*"정도" + 0.002*"무게" + 0.002*"기존" + 0.002*"입니다" + 0.002*"서피스프로" + 0.002*"프로" + 0.002*"기기" + 0.002*"성은"
# Topic: 65
# Words: 0.055*"디자인" + 0.055*"갘고" + 0.055*"호환" + 0.055*"노트북" + 0.055*"안되는" + 0.055*"사서" + 0.055*"불편" + 0.055*"마우스" + 0.055*"저렴하게" + 0.055*"좋아요"
# Topic: 66
# Words: 0.002*"향상" + 0.002*"가량" + 0.002*"재생" + 0.002*"정확도" + 0.002*"터치" + 0.002*"테스트" + 0.002*"필요할거고" + 0.002*"용감" + 0.002*"환경" + 0.002*"만족스럽니다"
# Topic: 67
# Words: 0.002*"향상" + 0.002*"가량" + 0.002*"재생" + 0.002*"정확도" + 0.002*"터치" + 0.002*"테스트" + 0.002*"필요할거고" + 0.002*"용감" + 0.002*"환경" + 0.002*"만족스럽니다"
# Topic: 68
# Words: 0.079*"서피스" + 0.041*"구매" + 0.036*"제품" + 0.021*"입니다" + 0.020*"다만" + 0.018*"노트북" + 0.016*"사용" + 0.016*"하나" + 0.016*"단자" + 0.016*"좋아요"
# Topic: 69
# Words: 0.002*"향상" + 0.002*"가량" + 0.002*"재생" + 0.002*"정확도" + 0.002*"터치" + 0.002*"테스트" + 0.002*"필요할거고" + 0.002*"용감" + 0.002*"환경" + 0.002*"만족스럽니다"
# Topic: 70
# Words: 0.002*"향상" + 0.002*"가량" + 0.002*"재생" + 0.002*"정확도" + 0.002*"터치" + 0.002*"테스트" + 0.002*"필요할거고" + 0.002*"용감" + 0.002*"환경" + 0.002*"만족스럽니다"
# Topic: 71
# Words: 0.097*"좋네요" + 0.097*"뱅킹" + 0.097*"사용" + 0.097*"서브" + 0.097*"가끔" + 0.001*"정확도" + 0.001*"터치" + 0.001*"테스트" + 0.001*"향상" + 0.001*"필요할거고"
# Topic: 72
# Words: 0.002*"향상" + 0.002*"가량" + 0.002*"재생" + 0.002*"정확도" + 0.002*"터치" + 0.002*"테스트" + 0.002*"필요할거고" + 0.002*"용감" + 0.002*"환경" + 0.002*"만족스럽니다"
# Topic: 73
# Words: 0.002*"향상" + 0.002*"가량" + 0.002*"재생" + 0.002*"정확도" + 0.002*"터치" + 0.002*"테스트" + 0.002*"필요할거고" + 0.002*"용감" + 0.002*"환경" + 0.002*"만족스럽니다"
# Topic: 74
# Words: 0.002*"향상" + 0.002*"가량" + 0.002*"재생" + 0.002*"정확도" + 0.002*"터치" + 0.002*"테스트" + 0.002*"필요할거고" + 0.002*"용감" + 0.002*"환경" + 0.002*"만족스럽니다"
# Topic: 75
# Words: 0.098*"게임" + 0.048*"튕기" + 0.048*"사지" + 0.048*"아님" + 0.048*"난리" + 0.048*"웬만한" + 0.048*"전부" + 0.048*"하나" + 0.048*"환불" + 0.018*"노트북"
# Topic: 76
# Words: 0.002*"향상" + 0.002*"가량" + 0.002*"재생" + 0.002*"정확도" + 0.002*"터치" + 0.002*"테스트" + 0.002*"필요할거고" + 0.002*"용감" + 0.002*"환경" + 0.002*"만족스럽니다"
# Topic: 77
# Words: 0.027*"때문" + 0.025*"환경" + 0.025*"사운드" + 0.024*"마이크" + 0.024*"용감" + 0.018*"문제" + 0.015*"있어요" + 0.015*"녹음" + 0.015*"어렵네요" + 0.014*"향상"
# Topic: 78
# Words: 0.082*"사용" + 0.053*"배터리" + 0.053*"문제" + 0.028*"정도" + 0.028*"다만" + 0.027*"보드" + 0.027*"모델" + 0.027*"발생" + 0.026*"만족스럽습니다" + 0.026*"어댑터"
# Topic: 79
# Words: 0.002*"향상" + 0.002*"가량" + 0.002*"재생" + 0.002*"정확도" + 0.002*"터치" + 0.002*"테스트" + 0.002*"필요할거고" + 0.002*"용감" + 0.002*"환경" + 0.002*"만족스럽니다"
# Topic: 80
# Words: 0.032*"서피스" + 0.014*"구매" + 0.014*"노트북" + 0.012*"사용" + 0.010*"입니다" + 0.010*"제품" + 0.007*"사은" + 0.007*"휴대" + 0.007*"때문" + 0.006*"장점"
# Topic: 81
# Words: 0.089*"고객" + 0.087*"센터" + 0.061*"답변" + 0.061*"프리" + 0.058*"리턴" + 0.056*"전화" + 0.030*"리퍼" + 0.030*"통해" + 0.030*"제품" + 0.030*"마이크로소프트"
# Topic: 82
# Words: 0.103*"완료" + 0.103*"업데이트" + 0.052*"배송" + 0.052*"제품" + 0.052*"안되더군요" + 0.052*"번개" + 0.052*"나머지" + 0.052*"완벽합니다" + 0.052*"사은" + 0.052*"얼굴인식"
# Topic: 83
# Words: 0.052*"구매" + 0.033*"문의" + 0.030*"있지만" + 0.029*"빨라" + 0.029*"좀더" + 0.029*"스프" + 0.029*"기간" + 0.029*"처음" + 0.029*"야합니다" + 0.028*"윈도우"
# Topic: 84
# Words: 0.002*"향상" + 0.002*"가량" + 0.002*"재생" + 0.002*"정확도" + 0.002*"터치" + 0.002*"테스트" + 0.002*"필요할거고" + 0.002*"용감" + 0.002*"환경" + 0.002*"만족스럽니다"
# Topic: 85
# Words: 0.036*"가격" + 0.030*"서피스" + 0.028*"구매" + 0.024*"제품" + 0.022*"정말" + 0.020*"사전예약" + 0.020*"좋고" + 0.016*"이제" + 0.016*"다만" + 0.015*"이유"
# Topic: 86
# Words: 0.064*"귀여워요" + 0.063*"조금" + 0.057*"자체" + 0.056*"불편하지만" + 0.052*"제품" + 0.046*"윈도우" + 0.045*"간지" + 0.001*"이하" + 0.001*"정확도" + 0.001*"용감"
# Topic: 87
# Words: 0.002*"향상" + 0.002*"가량" + 0.002*"재생" + 0.002*"정확도" + 0.002*"터치" + 0.002*"테스트" + 0.002*"필요할거고" + 0.002*"용감" + 0.002*"환경" + 0.002*"만족스럽니다"
# Topic: 88
# Words: 0.115*"충전" + 0.058*"전용" + 0.058*"충전기" + 0.058*"아쉬워요" + 0.058*"자석" + 0.058*"포트" + 0.058*"단자" + 0.058*"아니다" + 0.058*"마음" + 0.058*"정품"
# Topic: 89
# Words: 0.068*"간지" + 0.068*"윈도우" + 0.061*"제품" + 0.058*"불편하지만" + 0.057*"자체" + 0.052*"조금" + 0.051*"귀여워요" + 0.001*"이하" + 0.001*"정확도" + 0.001*"용감"
# Topic: 90
# Words: 0.002*"향상" + 0.002*"가량" + 0.002*"재생" + 0.002*"정확도" + 0.002*"터치" + 0.002*"테스트" + 0.002*"필요할거고" + 0.002*"용감" + 0.002*"환경" + 0.002*"만족스럽니다"
# Topic: 91
# Words: 0.002*"향상" + 0.002*"가량" + 0.002*"재생" + 0.002*"정확도" + 0.002*"터치" + 0.002*"테스트" + 0.002*"필요할거고" + 0.002*"용감" + 0.002*"환경" + 0.002*"만족스럽니다"
# Topic: 92
# Words: 0.107*"약간" + 0.107*"터치" + 0.107*"있어요" + 0.107*"안될되" + 0.001*"향상" + 0.001*"고개" + 0.001*"정확도" + 0.001*"테스트" + 0.001*"필요할거고" + 0.001*"이하"
# Topic: 93
# Words: 0.051*"서피스" + 0.039*"구매" + 0.025*"노트북" + 0.021*"제품" + 0.021*"사용" + 0.019*"입니다" + 0.015*"고려" + 0.013*"사은" + 0.011*"실망" + 0.011*"더욱"
# Topic: 94
# Words: 0.027*"노트북" + 0.015*"같은" + 0.013*"가장" + 0.013*"드래그" + 0.013*"사용" + 0.010*"대학생" + 0.010*"적당한" + 0.009*"처음" + 0.008*"보고" + 0.008*"있어요"
# Topic: 95
# Words: 0.002*"향상" + 0.002*"가량" + 0.002*"재생" + 0.002*"정확도" + 0.002*"터치" + 0.002*"테스트" + 0.002*"필요할거고" + 0.002*"용감" + 0.002*"환경" + 0.002*"만족스럽니다"
# Topic: 96
# Words: 0.065*"태블릿" + 0.043*"터치" + 0.043*"제품" + 0.043*"사운드" + 0.022*"후기" + 0.022*"부드럽게" + 0.022*"설명" + 0.022*"필름" + 0.022*"필요합니다" + 0.022*"좋음"
# Topic: 97
# Words: 0.002*"향상" + 0.002*"가량" + 0.002*"재생" + 0.002*"정확도" + 0.002*"터치" + 0.002*"테스트" + 0.002*"필요할거고" + 0.002*"용감" + 0.002*"환경" + 0.002*"만족스럽니다"
# Topic: 98
# Words: 0.078*"노트북" + 0.029*"드래그" + 0.029*"사용" + 0.029*"가장" + 0.029*"같은" + 0.019*"처음" + 0.019*"터치패드" + 0.019*"있어요" + 0.019*"보고" + 0.018*"적당한"
# Topic: 99
# Words: 0.002*"향상" + 0.002*"가량" + 0.002*"재생" + 0.002*"정확도" + 0.002*"터치" + 0.002*"테스트" + 0.002*"필요할거고" + 0.002*"용감" + 0.002*"환경" + 0.002*"만족스럽니다"

# %%
#긍정적 리뷰와 가장 흔한 단어들과 그 빈도수 출력
all_words = [word for doc in high_rating_data_clean for word in doc]
word_counts = Counter(all_words)

# 가장 흔한 단어들과 그 빈도수 출력
most_common_words = word_counts.most_common(30)
for word, count in most_common_words:
    print(f'Word: {word}, Frequency: {count}')
# Out:
# Word: 사용, Frequency: 277
# Word: 서피스, Frequency: 203
# Word: 구매, Frequency: 161
# Word: 배송, Frequency: 161
# Word: 노트북, Frequency: 148
# Word: 제품, Frequency: 127
# Word: 입니다, Frequency: 111
# Word: 프로, Frequency: 93
# Word: 태블릿, Frequency: 89
# Word: 가격, Frequency: 80
# Word: 좋아요, Frequency: 79
# Word: 좋습니다, Frequency: 76
# Word: 윈도우, Frequency: 74
# Word: 좋은, Frequency: 74
# Word: 생각, Frequency: 72
# Word: 보드, Frequency: 67
# Word: 만족합니다, Frequency: 65
# Word: 있습니다, Frequency: 64
# Word: 성능, Frequency: 62
# Word: 빠르고, Frequency: 62
# Word: 정말, Frequency: 62
# Word: 고민, Frequency: 59
# Word: 휴대, Frequency: 58
# Word: 좋네요, Frequency: 58
# Word: 작업, Frequency: 51
# Word: 서피스프로, Frequency: 49
# Word: 아주, Frequency: 49
# Word: 빠른, Frequency: 45
# Word: 업무, Frequency: 43
# Word: 매우, Frequency: 42

# %%
# 부정적 리뷰와 가장 흔한 단어들과 그 빈도수 출력
all_words_negative = [word for doc in low_rating_data_clean for word in doc]
word_counts_negative = Counter(all_words_negative)
most_common_words_negative = word_counts_negative.most_common(20)
for word, count in most_common_words_negative:
    print(f'Word: {word}, Frequency: {count}')
# Out:
# Word: 사용, Frequency: 25
# Word: 서피스, Frequency: 22
# Word: 제품, Frequency: 19
# Word: 노트북, Frequency: 16
# Word: 구매, Frequency: 15
# Word: 입니다, Frequency: 14
# Word: 프로, Frequency: 9
# Word: 다만, Frequency: 8
# Word: 보드, Frequency: 7
# Word: 정도, Frequency: 6
# Word: 좋습니다, Frequency: 6
# Word: 같아요, Frequency: 6
# Word: 가격, Frequency: 6
# Word: 좋아요, Frequency: 6
# Word: 문제, Frequency: 6
# Word: 터치, Frequency: 6
# Word: 배송, Frequency: 6
# Word: 태블릿, Frequency: 5
# Word: 휴대, Frequency: 5
# Word: 윈도우, Frequency: 5

# %%
# 각 주제별 상위 단어 추출
def get_top_words(model, num_words=10):
    top_words = []
    for idx, topic in model.print_topics(-1):
        for word in topic.split('+'):
            top_word = word.split('*')[1].strip().replace('"', '')
            top_words.append(top_word)
    return top_words

# 전체 데이터, 긍정적 리뷰와 부정적 리뷰 모델에서 상위 단어 추출
top_words_positive = get_top_words(positive_model, 10)
top_words_negative = get_top_words(negative_model, 10)

combined_word_counts = Counter(top_words_positive + top_words_negative)
print("전체 데이터셋에서 일관성 있는 상위 10개 단어:")
for word, count in combined_word_counts.most_common(10):
    print(f'Word: {word}, Frequency: {count}')

# 긍정적 리뷰 데이터셋에서 상위 10개 단어 선택
positive_word_counts = Counter(top_words_positive)
print("\n긍정적 리뷰에서 상위 10개 단어:")
for word, count in positive_word_counts.most_common(10):
    print(f'Word: {word}, Frequency: {count}')

# 부정적 리뷰 데이터셋에서 상위 10개 단어 선택
negative_word_counts = Counter(top_words_negative)
print("\n부정적 리뷰에서 상위 10개 단어:")
for word, count in negative_word_counts.most_common(10):
    print(f'Word: {word}, Frequency: {count}')
# Out:
# 전체 데이터셋에서 일관성 있는 상위 10개 단어:
# Word: 사용, Frequency: 86
# Word: 터치, Frequency: 67
# Word: 정확도, Frequency: 62
# Word: 테스트, Frequency: 61
# Word: 서피스, Frequency: 60
# Word: 환경, Frequency: 58
# Word: 향상, Frequency: 58
# Word: 필요할거고, Frequency: 58
# Word: 용감, Frequency: 58
# Word: 재생, Frequency: 57
#
# 긍정적 리뷰에서 상위 10개 단어:
# Word: 사용, Frequency: 64
# Word: 서피스, Frequency: 48
# Word: 구매, Frequency: 41
# Word: 배송, Frequency: 41
# Word: 노트북, Frequency: 39
# Word: 제품, Frequency: 31
# Word: 입니다, Frequency: 29
# Word: 프로, Frequency: 24
# Word: 태블릿, Frequency: 20
# Word: 좋습니다, Frequency: 19
#
# 부정적 리뷰에서 상위 10개 단어:
# Word: 터치, Frequency: 63
# Word: 정확도, Frequency: 62
# Word: 테스트, Frequency: 61
# Word: 향상, Frequency: 58
# Word: 필요할거고, Frequency: 58
# Word: 용감, Frequency: 58
# Word: 재생, Frequency: 57
# Word: 환경, Frequency: 56
# Word: 가량, Frequency: 54
# Word: 만족스럽니다, Frequency: 51
